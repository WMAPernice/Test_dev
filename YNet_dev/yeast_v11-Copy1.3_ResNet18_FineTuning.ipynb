# %% [markdown]
# ### Importing utilities:

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
import skimage.external.tifffile as tiff

from common import Statistics, dataset_source
from resources.conv_learner import *
from resources.plots import *
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Setting up variables

# %%
PATH = "datasets/yeast_v11.3/"
data_path = Path(PATH)

# %%
CLASSES = ('WT', 'CK666', 'Lat5uM', 'LatA05uM', 'DMSO', 'Eth', 'DTT', 'H2O2')
NUM_CLASSES = len(CLASSES)
BATCH_SIZE = 64
SIZE = [2,224,224]

# %%
NUM_CLASSES
# Out:
# 8

# %% [markdown]
# #### Calculating normalization statistics
#
# Note that we are setting up train & val data, as well as test. Within test, we are here including a mutant cell type that the model never trains on. The idea is to use to the feature space developed during training to evaluate novel cell types by similarity to the landmarks that the model was trained on.

# %%
# classes = Statistics.source_class(data_path)

# train_val = zip(classes['train'], classes['val'])
# test_ = zip(classes['test'])


# stats_name = "yeast_v11.1_per_class.dict"
# main_stats = Statistics.per_class(train_val, save_name = stats_name)
# test_stats = Statistics.per_class(test_)

# %%
# for keys in main_stats.keys():
#     print(f"{keys}: \t \t \t {main_stats[keys]}")

# %%
# for keys in test_stats.keys():
#     print(f"{keys}: \t \t \t {test_stats[keys]}")

# %% [markdown]
# ## Defining datasets:

# %%
def tfms_for_test(sz):
    test_norm = Normalize(stats=None, IntNorm=True)
    test_denorm = None
    val_crop = CropType.NO
    test_tfms = image_gen(test_norm, test_denorm,sz, crop_type=val_crop)
    return test_tfms

# %%
def get_data(path: str, sz, bs): # , num_workers=1
    create, lbl2index, lbl2index_test = ImageClassifierData.prepare_from_path(path, val_name='val', bs=bs, num_workers = 8,
                                                                             balance=True)
    augs = [RandomDihedral(),
#             Random_brightness(),
            RandomRotate(90),
#             Gauss_noise(stats = main_stats_X, IntNorm=True)
           ]
    
    tfms = tfms_with_IntNorm(sz, aug_tfms=augs, crop_type=CropType.CENTER, pad=sz[1]//8)
    test_tfms = tfms_for_test(sz)
    tfms += (test_tfms, )
    
    return create(tfms), lbl2index, lbl2index_test

# %%
data, lbl2idx, lbl2idx_test = get_data(PATH,SIZE,BATCH_SIZE)
# Out:
# Internal Normalization
# val_crop is: 2
# Internal Normalization
# Using WeightedRandomSampler

# %%
data.classes
# Out:
# ['mmm1KO',
#  'num1KO',
#  'WT',
#  'mfb1KO',
#  'mmr1KO',
#  'CK666',
#  'LatA-5uM',
#  'dnm1KO',
#  'fzo1KO']

# %%
x , y = next(iter(data.trn_dl))

# %%
print(data.test_aug_dl.dataset.transform.tfms)

# %% [markdown]
# ### Inspect loaded data:
#
# Displaying the same image with and without normalization.

# %%
# print transformations
plt.style.use('seaborn-white')

c = 0
idx = 0
fig, ax = plt.subplots(2,4, figsize=(16,10))
for i, ax in enumerate(ax.flat):
    x, y = next(iter(data.aug_dl))
    im = to_np(x)[idx]
    ax.imshow(np.sum(im, axis = 0))
#     ax.imshow(im[c])

# %%
plt.style.use('seaborn-white')

# %%
def load_epoch(dl = data.trn_dl):
    
    batch = iter(dl)

    xs = []
    ys = []

    for b in range(0,len(dl)):
        x_, y_ = next(batch)
        x_np, y_np = to_np(x_), to_np(y_)
        xs.append(x_np)
        ys.append(y_np)

    return np.vstack(xs), np.concatenate(ys)

# %%
xs, ys =  load_epoch()

# %%
import seaborn as sns

# %%
fig, axarr = plt.subplots(1, 2, figsize=(14, 8))

for i in [2,3]:
    
    xs_clss = xs[ys == i] 
    xs_sub = xs_clss[:100,...]
    xs_sub = xs_sub.reshape(-1,2,50176)
    
    ch0, ch1 = np.ravel(xs_sub[:,0]), np.ravel(xs_sub[:,1])
    print(ch1.shape)

    sns.kdeplot(ch0, ax = axarr[0], label = data.classes[i])
    sns.kdeplot(ch1, ax = axarr[1], label = data.classes[i])
    
# axarr[0].set_xlim(-12,12);
# axarr[1].set_xlim(-10,18);   
# axarr[0].set_ylim(0,0.8);
# axarr[1].set_ylim(0,1.8);
axarr[1].legend()

# %%
print(len(data.val_dl.dataset.y))
print(len(data.trn_dl.dataset.y))
print(len(data.test_dl.dataset.y))

# %% [markdown]
# # Training setup

# %%
torch.cuda.is_available()

# %% [markdown]
# ## ResNet_with_Batchnorm
#
# Defining network architecture.

# %%
arch = resnet18_c
# arch = resnet34_c

# %%
learn = ConvLearner.pretrained(arch, data, ps=0.25, opt_fn=optim.Adam, pretrained=False)

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 2, 224, 224]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', False),
#                            ('nb_params', 6272)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-11',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-13',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-14',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-18',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('Conv2d-24',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-25',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-26',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-27',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-34',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-42',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-43',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-44',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-45',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-46',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-47',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-48',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-49',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-50',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1179648)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-56',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-57',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-58',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-59',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-66',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-67',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-68',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-69',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-70',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-71',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Dropout-72',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('Linear-73',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 524800)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-75',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-76',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-77',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 9]),
#                            ('trainable', True),
#                            ('nb_params', 4617)])),
#              ('LogSoftmax-78',
#               OrderedDict([('input_shape', [-1, 9]),
#                            ('output_shape', [-1, 9]),
#                            ('nb_params', 0)]))])

# %%
# Print model's state_dict
print("Model's state_dict:")
for param_tensor in learn.models.model.state_dict():
    print(param_tensor, "\t", learn.models.model.state_dict()[param_tensor].size())
# Out:
# Model's state_dict:
# 0.weight 	 torch.Size([64, 2, 7, 7])
# 1.weight 	 torch.Size([64])
# 1.bias 	 torch.Size([64])
# 1.running_mean 	 torch.Size([64])
# 1.running_var 	 torch.Size([64])
# 4.0.conv1.weight 	 torch.Size([64, 64, 3, 3])
# 4.0.bn1.weight 	 torch.Size([64])
# 4.0.bn1.bias 	 torch.Size([64])
# 4.0.bn1.running_mean 	 torch.Size([64])
# 4.0.bn1.running_var 	 torch.Size([64])
# 4.0.conv2.weight 	 torch.Size([64, 64, 3, 3])
# 4.0.bn2.weight 	 torch.Size([64])
# 4.0.bn2.bias 	 torch.Size([64])
# 4.0.bn2.running_mean 	 torch.Size([64])
# 4.0.bn2.running_var 	 torch.Size([64])
# 4.1.conv1.weight 	 torch.Size([64, 64, 3, 3])
# 4.1.bn1.weight 	 torch.Size([64])
# 4.1.bn1.bias 	 torch.Size([64])
# 4.1.bn1.running_mean 	 torch.Size([64])
# 4.1.bn1.running_var 	 torch.Size([64])
# 4.1.conv2.weight 	 torch.Size([64, 64, 3, 3])
# 4.1.bn2.weight 	 torch.Size([64])
# 4.1.bn2.bias 	 torch.Size([64])
# 4.1.bn2.running_mean 	 torch.Size([64])
# 4.1.bn2.running_var 	 torch.Size([64])
# 5.0.conv1.weight 	 torch.Size([128, 64, 3, 3])
# 5.0.bn1.weight 	 torch.Size([128])
# 5.0.bn1.bias 	 torch.Size([128])
# 5.0.bn1.running_mean 	 torch.Size([128])
# 5.0.bn1.running_var 	 torch.Size([128])
# 5.0.conv2.weight 	 torch.Size([128, 128, 3, 3])
# 5.0.bn2.weight 	 torch.Size([128])
# 5.0.bn2.bias 	 torch.Size([128])
# 5.0.bn2.running_mean 	 torch.Size([128])
# 5.0.bn2.running_var 	 torch.Size([128])
# 5.0.downsample.0.weight 	 torch.Size([128, 64, 1, 1])
# 5.0.downsample.1.weight 	 torch.Size([128])
# 5.0.downsample.1.bias 	 torch.Size([128])
# 5.0.downsample.1.running_mean 	 torch.Size([128])
# 5.0.downsample.1.running_var 	 torch.Size([128])
# 5.1.conv1.weight 	 torch.Size([128, 128, 3, 3])
# 5.1.bn1.weight 	 torch.Size([128])
# 5.1.bn1.bias 	 torch.Size([128])
# 5.1.bn1.running_mean 	 torch.Size([128])
# 5.1.bn1.running_var 	 torch.Size([128])
# 5.1.conv2.weight 	 torch.Size([128, 128, 3, 3])
# 5.1.bn2.weight 	 torch.Size([128])
# 5.1.bn2.bias 	 torch.Size([128])
# 5.1.bn2.running_mean 	 torch.Size([128])
# 5.1.bn2.running_var 	 torch.Size([128])
# 6.0.conv1.weight 	 torch.Size([256, 128, 3, 3])
# 6.0.bn1.weight 	 torch.Size([256])
# 6.0.bn1.bias 	 torch.Size([256])
# 6.0.bn1.running_mean 	 torch.Size([256])
# 6.0.bn1.running_var 	 torch.Size([256])
# 6.0.conv2.weight 	 torch.Size([256, 256, 3, 3])
# 6.0.bn2.weight 	 torch.Size([256])
# 6.0.bn2.bias 	 torch.Size([256])
# 6.0.bn2.running_mean 	 torch.Size([256])
# 6.0.bn2.running_var 	 torch.Size([256])
# 6.0.downsample.0.weight 	 torch.Size([256, 128, 1, 1])
# 6.0.downsample.1.weight 	 torch.Size([256])
# 6.0.downsample.1.bias 	 torch.Size([256])
# 6.0.downsample.1.running_mean 	 torch.Size([256])
# 6.0.downsample.1.running_var 	 torch.Size([256])
# 6.1.conv1.weight 	 torch.Size([256, 256, 3, 3])
# 6.1.bn1.weight 	 torch.Size([256])
# 6.1.bn1.bias 	 torch.Size([256])
# 6.1.bn1.running_mean 	 torch.Size([256])
# 6.1.bn1.running_var 	 torch.Size([256])
# 6.1.conv2.weight 	 torch.Size([256, 256, 3, 3])
# 6.1.bn2.weight 	 torch.Size([256])
# 6.1.bn2.bias 	 torch.Size([256])
# 6.1.bn2.running_mean 	 torch.Size([256])
# 6.1.bn2.running_var 	 torch.Size([256])
# 7.0.conv1.weight 	 torch.Size([512, 256, 3, 3])
# 7.0.bn1.weight 	 torch.Size([512])
# 7.0.bn1.bias 	 torch.Size([512])
# 7.0.bn1.running_mean 	 torch.Size([512])
# 7.0.bn1.running_var 	 torch.Size([512])
# 7.0.conv2.weight 	 torch.Size([512, 512, 3, 3])
# 7.0.bn2.weight 	 torch.Size([512])
# 7.0.bn2.bias 	 torch.Size([512])
# 7.0.bn2.running_mean 	 torch.Size([512])
# 7.0.bn2.running_var 	 torch.Size([512])
# 7.0.downsample.0.weight 	 torch.Size([512, 256, 1, 1])
# 7.0.downsample.1.weight 	 torch.Size([512])
# 7.0.downsample.1.bias 	 torch.Size([512])
# 7.0.downsample.1.running_mean 	 torch.Size([512])
# 7.0.downsample.1.running_var 	 torch.Size([512])
# 7.1.conv1.weight 	 torch.Size([512, 512, 3, 3])
# 7.1.bn1.weight 	 torch.Size([512])
# 7.1.bn1.bias 	 torch.Size([512])
# 7.1.bn1.running_mean 	 torch.Size([512])
# 7.1.bn1.running_var 	 torch.Size([512])
# 7.1.conv2.weight 	 torch.Size([512, 512, 3, 3])
# 7.1.bn2.weight 	 torch.Size([512])
# 7.1.bn2.bias 	 torch.Size([512])
# 7.1.bn2.running_mean 	 torch.Size([512])
# 7.1.bn2.running_var 	 torch.Size([512])
# 10.weight 	 torch.Size([1024])
# 10.bias 	 torch.Size([1024])
# 10.running_mean 	 torch.Size([1024])
# 10.running_var 	 torch.Size([1024])
# 12.weight 	 torch.Size([512, 1024])
# 12.bias 	 torch.Size([512])
# 14.weight 	 torch.Size([512])
# 14.bias 	 torch.Size([512])
# 14.running_mean 	 torch.Size([512])
# 14.running_var 	 torch.Size([512])
# 16.weight 	 torch.Size([9, 512])
# 16.bias 	 torch.Size([9])

# %%
len(loaded_state.keys())
# Out:
# 112

# %%
import copy

def check_model_loading(learn_obj, loaded_state_dict):
    learn_weight0 = list(copy.deepcopy(learn_obj.models.model.state_dict()).items())[0] # need deepcopy here
    learn_weight10 = list(copy.deepcopy(learn_obj.models.model.state_dict()).items())[100] # need deepcopy here

    learn_obj.models.model.load_state_dict(loaded_state_dict, strict=False)
    learn_weight0_loaded = list(learn_obj.models.model.state_dict().items())[0]
    learn_weight10_loaded = list(learn_obj.models.model.state_dict().items())[100]

    print('weights_0:')
    print(learn_weight0[1][0] - learn_weight0_loaded[1][0])
    print('weights_10:')
    print(learn_weight10[1][0] - learn_weight10_loaded[1][0])

# %%
saved_state_dict_path = 'datasets/yeast_v11.3/models/yeast_v11.3_ResNet18_v8_save.h5'
loaded_state_dict = torch.load(saved_state_dict_path)

# %%
# truncating saved model_state_dict()

loaded_state_dict_trunc = copy.deepcopy(loaded_state_dict)
del_keys = list(loaded_state_dict_trunc.keys())[100:]
for key in del_keys: del loaded_state_dict_trunc[key]

print('loaded_state_dict # keys: ', len(loaded_state_dict.keys()))    
print('loaded_state_dict_trunc # keys: ', len(loaded_state_dict_trunc.keys()))    

# Print model's state_dict
# print("Model's state_dict:")
# for param_tensor in loaded_state_dict_trunc:
#     print(param_tensor, "\t", loaded_state_dict_trunc[param_tensor].size())
# Out:
# loaded_state_dict # keys:  112
# loaded_state_dict_trunc # keys:  100

# %%
learn = ConvLearner.pretrained(arch, data, ps=0.25, opt_fn=optim.Adam, pretrained=False)
check_model_loading(learn, loaded_state_dict)
# Out:
# weights_0:
#
# (0 ,.,.) =
#  -0.0157  0.0433  0.0254  0.0431  0.0194  0.0238 -0.0106
#   0.0869  0.0538  0.0880  0.0513  0.0803  0.0002  0.0690
#   0.0315  0.0027  0.0826  0.0874  0.0444  0.0947  0.0530
#   0.0462  0.0884  0.0735  0.1468  0.0352  0.0883  0.0736
#   0.0447  0.0260  0.1184  0.1466  0.1054  0.0462  0.1020
#   0.0582  0.0458  0.0141  0.1133  0.0340  0.0971  0.0450
#   0.0278  0.0863  0.0981  0.0453  0.0005  0.0377  0.0688
#
# (1 ,.,.) =
#   0.0802 -0.0018  0.0180 -0.0225  0.0804  0.0949  0.0702
#  -0.0503 -0.0868 -0.0892 -0.1486 -0.0515 -0.0757 -0.0358
#  -0.0148 -0.1219 -0.1371 -0.1636 -0.1249 -0.1168 -0.0306
#  -0.0425 -0.2118 -0.2028 -0.2804 -0.2554 -0.1436 -0.1228
#  -0.0894 -0.2030 -0.2684 -0.2962 -0.2485 -0.1879 -0.1348
#  -0.0608 -0.1803 -0.2246 -0.2562 -0.2032 -0.1608 -0.0826
#  -0.0717 -0.2578 -0.2193 -0.2559 -0.2191 -0.1708 -0.1361
# [torch.cuda.FloatTensor of size 2x7x7 (GPU 0)]
#
# weights_10:
# 0.24915185570716858

# %%
learn = ConvLearner.pretrained(arch, data, ps=0.25, opt_fn=optim.Adam, pretrained=False)
check_model_loading(learn, loaded_state_dict_trunc )
# Out:
# weights_0:
#
# (0 ,.,.) =
#   0.0310  0.0382  0.0744  0.0786  0.0104  0.0094 -0.0486
#   0.0378  0.0511  0.0608  0.0360  0.0906  0.0538  0.0321
#   0.0598 -0.0177  0.0598  0.0907  0.0882  0.0616  0.0602
#   0.0144  0.0649  0.1061  0.1629  0.0331  0.0362  0.0845
#   0.0118  0.0131  0.1176  0.0881  0.1198  0.0372  0.0549
#   0.0163  0.0566 -0.0033  0.1290  0.0153  0.1059  0.0249
#   0.0200  0.0405  0.0812  0.0730  0.0314  0.0523  0.0334
#
# (1 ,.,.) =
#   0.0922 -0.0348  0.0356 -0.0061  0.0525  0.1160  0.0073
#  -0.0025 -0.1429 -0.0376 -0.1165 -0.1585 -0.0664 -0.0046
#  -0.0204 -0.1171 -0.0900 -0.1563 -0.1553 -0.1440 -0.0904
#  -0.0764 -0.1663 -0.2357 -0.2472 -0.2169 -0.1011 -0.1072
#  -0.0337 -0.1893 -0.2406 -0.2963 -0.2815 -0.1868 -0.1293
#  -0.0440 -0.1877 -0.2241 -0.2747 -0.2054 -0.1514 -0.1146
#  -0.0847 -0.2138 -0.2313 -0.3041 -0.1987 -0.1591 -0.1729
# [torch.cuda.FloatTensor of size 2x7x7 (GPU 0)]
#
# weights_10:
# 0.0

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 2, 224, 224]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', False),
#                            ('nb_params', 6272)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-11',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-13',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-14',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-18',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('Conv2d-24',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-25',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-26',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-27',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-34',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-42',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-43',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-44',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-45',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-46',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-47',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-48',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-49',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-50',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1179648)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-56',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-57',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-58',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-59',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-66',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-67',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-68',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-69',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-70',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-71',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Dropout-72',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('Linear-73',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 524800)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-75',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-76',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-77',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 9]),
#                            ('trainable', True),
#                            ('nb_params', 4617)])),
#              ('LogSoftmax-78',
#               OrderedDict([('input_shape', [-1, 9]),
#                            ('output_shape', [-1, 9]),
#                            ('nb_params', 0)]))])

# %%
wd=1e-5 # weight-decay/L2 regularization

# %%
learn.unfreeze()

# %%
learn.lr_find(1e-10)

# %%
learn.sched.plot()

# %%
# %time learn.fit(1e-2, 8, cycle_len=1, wds=wd, use_wd_sched=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=8), HTML(value='')))
# EPOCH 0 ---------------------------------------- STEP 0
# epoch      trn_loss   val_loss   accuracy
#     0      0.515713   0.452864   0.833333
# EPOCH 1 ---------------------------------------- STEP 1
#     1      0.362339   0.377084   0.853968
# EPOCH 2 ---------------------------------------- STEP 2
#     2      0.293672   0.3405     0.871429
# EPOCH 3 ---------------------------------------- STEP 3
#     3      0.255454   0.364532   0.873016
# EPOCH 4 ---------------------------------------- STEP 4
#     4      0.248404   0.390319   0.863492
# EPOCH 5 ---------------------------------------- STEP 5
#     5      0.237745   0.356944   0.865079
# EPOCH 6 ---------------------------------------- STEP 6
#     6      0.220033   0.312469   0.885714
# EPOCH 7 ---------------------------------------- STEP 7
#     7      0.190826   0.341357   0.879365
#
# appending existing log-files...
# log-files saved to: datasets/yeast_v11.3/
# Wall time: 1min 36s
# [array([0.34136]), 0.8793650812572903]

# %%
learn.unfreeze()

# %%
lrs = np.array([1e-6,1e-4,1e-2])

# %%
# %time learn.fit(lrs, 8, cycle_len=1, wds=wd, use_wd_sched=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=8), HTML(value='')))
# EPOCH 0 ---------------------------------------- STEP 18
# epoch      trn_loss   val_loss   accuracy
#     0      0.30822    0.472646   0.839683
# EPOCH 1 ---------------------------------------- STEP 19
#     1      0.27891    0.427656   0.853968
# EPOCH 2 ---------------------------------------- STEP 20
#     2      0.261778   0.378352   0.869841
# EPOCH 3 ---------------------------------------- STEP 21
#     3      0.253252   0.420313   0.868254
# EPOCH 4 ---------------------------------------- STEP 22
#     4      0.250426   0.380044   0.871429
# EPOCH 5 ---------------------------------------- STEP 23
#     5      0.270833   0.411013   0.865079
# EPOCH 6 ---------------------------------------- STEP 24
#     6      0.240509   0.456801   0.855556
# EPOCH 7 ---------------------------------------- STEP 25
#     7      0.234838   0.413679   0.866667
# appending existing log-files...
# log-files saved to: datasets/yeast_v11.3/
# Wall time: 3min 44s
# [array([0.41368]), 0.8666666643960136]

# %%
# %time learn.fit(1e-2, 8, cycle_len=1, wds=wd, use_wd_sched=True)

# %%
f = plt.figure()
x = learn.sched.plot_loss()
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.show()

# %%
learn.sched.plot_lr()

# %%
# %time learn.fit(4e-3, 2, cycle_len=8, wds=wd, use_wd_sched=True)

# %%
learn.save('yeast_v11.3_ResNet18_82_v1')

# %%
learn.load('yeast_v11.3_ResNet18_82_v1')

# %% [markdown]
# #### Run some more cylces - error & accuracy should continuously improve
#
# Note: cycle len = number of epochs per cycle

# %%
# %time learn.fit(4e-3, 2, cycle_len=8, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v2')

# %%
learn.save('yeast_v11.3_ResNet18_85_v2')

# %%
# %time learn.fit(1e-3, 1, cycle_len=8, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v3')

# %%
# %time learn.fit(8e-4, 1, cycle_len=8, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v4')

# %%
# %time learn.fit(6e-4, 1, cycle_len=12, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v5')

# %%
# %time learn.fit(4e-4, 1, cycle_len=12, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v6')

# %%
# %time learn.fit(1e-4, 1, cycle_len=24, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v7')

# %%
# %time learn.fit(4e-5, 2, cycle_len=12, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v7')

# %%
# %time learn.fit(1e-3, 2, cycle_len=8, cycle_mult=2, wds=wd, use_wd_sched=True, best_save_name='yeast_v11.3_ResNet18_v8')

# %%
learn.save('yeast_v11.3_ResNet18_v8_save')

# %%
# %time learn.fit(1e-4, 1, cycle_len=5, wds=wd, use_wd_sched=True, use_clr=(20,8, 0.95, 0.85))

# %%
# %time learn.fit(1e-10, 1, cycle_len=3, wds=wd, use_wd_sched=True, use_clr=(20,8, 0.95, 0.85))

# %%
print(lbl2idx)

# %%
learn.summary()

# %%
learn.models.model

# %%
learn.freeze_to(2)

# %%
adjust = {0:22,
          1:14,
#           2:22,
          3:3,
          4:3,
         5:14,
         6:14
         }

# use_clr=(20,8, 0.95, 0.85),
# %time learn.fit(1e-3, 1, cycle_len=8, wds=wd, use_wd_sched=True, adjust_class=adjust, best_save_name='YNet_v11.1_ResNet34_dihedral_ps025_IntNorm_rot90_rGauss_balanced_86_FT_mmr1')

# %% [markdown]
# ## Analysis/Model evaluation
#
# This is one of the major areas that needs improvement in our workflow. The tools we have so far (confusion matrix and manual inpsection of images) are essential but definitely not sufficient to ensure that our model learns something biologicaly relevant. Ideas are welcome!

# %% [markdown]
# ### ...after training

# %%
learn.save('YNet_v11.2_ResNet18_dihedral_ps025_IntNorm_rot90_rGauss_balanced_92')

# %%
## Load model:
learn.load('yeast_v11.3_ResNet18_v4')

# %%
data2, lbl2idx, lbl2idx_test = get_data(PATH,SIZE,BATCH_SIZE)

# %%
learn.set_data(data2)

# %%
learn.freeze()

# %%
# %time learn.fit(1e-3, 1, cycle_len=1, wds=wd, use_wd_sched=True, use_clr=(20,8, 0.95, 0.85))

# %%
learn.lr_find()

# %%
learn.warm_up(1e-10)

# %%
log_preds, y = learn.TTA(8) # run predictions with TTA

# %%
len(data.trn_ds.fnames) / 14

# %% [markdown]
# ### Cross_validation evaluation

# %%
# Plot confusion matrix 
plt.style.use('seaborn-white')
log_preds_mean = np.mean(log_preds, axis=0)
preds = np.argmax(log_preds_mean, axis=1)
cm = confusion_matrix(preds,y)
plot_confusion_matrix(cm, data.classes)

# %%
targ_names = ['mmm1KO', 'num1KO', 'WT', 'mfb1KO', 'mmr1KO', 'CK666', 'LatA', 'dnm1KO', 'fzo1KO']

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(accuracy_score(preds, y))

print(classification_report(preds, y, target_names=data.classes))

# %%
preds_noAct = []
y_noAct = []
for i in [2,3,4,0,1,7,8]:
    preds_noAct.extend(preds[y == i])
    y_noAct.extend(y[y==i])
    
print(accuracy_score(preds_noAct, y_noAct))
print(classification_report(preds_noAct, y_noAct, target_names=['WT', 'mfb1KO', 'mmr1KO', 'mmm1KO', 'num1KO', 'dnm1KO', 'fzo1KO']))

# %%
len(y_noAct), len(preds_noAct)

# %% [markdown]
# ## Test-set eval

# %%
learn.models.model

# %%
# function to be called by register_forward_hook

def get_embeddings(layer_name):
    def register_hook(layer_name):
        def get_embedding(layer, inp, outp):
            tmp = inp[0]
            embedding.append(tmp)

        hook = layer.register_forward_hook(get_embedding) 
        
        for i in ['trn', 'val', 'test']:
            embedding = []
            preds, y = learn.predict_with_targs(i)
            
            # populating dict, consiting of [0]: preds, [1]: y, [2]: activations[layer]
            embeddings[i] = [preds, y, np.vstack(to_np(embedding))]
            
        hook.remove()
        
    embeddings = {}    
    layer = learn.models.model._modules.get(layer_name)
    register_hook(layer)
    
    return embeddings

# %%
embeddings = get_embeddings('14')

# %%
# unpacking embeddings

embs_trn = embeddings['trn'][2]
y_trn = embeddings['trn'][1]

embs_val = embeddings['val'][2]
y_val = embeddings['val'][1]

embs_test = embeddings['test'][2]
y_test = embeddings['test'][1]

print(embs_trn.shape)
print(embs_val.shape)
print(embs_test.shape)

print(y_trn.shape)
print(y_val.shape)
print(y_test.shape)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# running PCA on embeddings
pca = []
n_components = 50
pca = PCA(n_components)

trn_pca_result = pca.fit_transform(embs_trn)
val_pca_result = pca.transform(embs_val)
test_pca_result = pca.transform(embs_test)

# %%
#plotting compenent-wise cumulative explained variance (for PCA)

plt.plot(range(n_components), pca.explained_variance_ratio_)
plt.plot(range(n_components), np.cumsum(pca.explained_variance_ratio_))
plt.title("Component-wise and Cumulative Explained Variance")

# %%
# running TSNE on embeddings

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(embs_trn)

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in range(9):
    PCA_cls = trn_pca_result[y_trn == i]
    TSNE_cls = tsne_results[y_trn == i]
    
    axarr[0].scatter(PCA_cls[:,compA], PCA_cls[:,compB], label = data.classes[i], s = 5)
    axarr[1].scatter(TSNE_cls[:,compA], TSNE_cls[:,compB], label = data.classes[i], s =5)
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in range(7):
    trn_PCA_cls = trn_pca_result[y_trn == i]
    val_PCA_cls = val_pca_result[y_val == i]

    axarr[0].scatter(trn_PCA_cls[:,compA], trn_PCA_cls[:,compB], label = data.classes[i])
    axarr[1].scatter(val_PCA_cls[:,compA], val_PCA_cls[:,compB], label = data.classes[i])
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
print(lbl2idx_test)

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in range(7):
    trn_PCA_cls = trn_pca_result[y_trn == i]

    axarr[0].scatter(trn_PCA_cls[:,compA], trn_PCA_cls[:,compB], label = data.classes[i])
    axarr[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    axarr[0].set_xlim(-15,45)
    axarr[0].set_ylim(-20,20)
    
for i in [0,1,3]:
    test_PCA_cls = test_pca_result[y_test == i]
    axarr[1].scatter(test_PCA_cls[:,compA], test_PCA_cls[:,compB], label = list(lbl2idx_test.keys())[i])
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    axarr[1].set_xlim(-15,45)
    axarr[1].set_ylim(-20,20)

# %%
list(lbl2idx_test.keys())[0]

# %%
# Generate 3D TSNE space from PCA of embeddings

tsne3D = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300, learning_rate=50.0)
PCA2tSNE_results_3D = tsne3D.fit_transform(embs)

# %%
tsne3D

# %%
from mpl_toolkits import mplot3d

# magic command to make plots interactive.
# restart kernel if you want to switch to e.g. %matplotlib inline
# %matplotlib notebook

# %%
# 3D plotting - very slow interactivity atm...

fig = plt.figure()
ax = plt.axes(projection='3d')

compA = 0
compB = 1
compC = 2

for i in range(10):
    clss = PCA2tSNE_results_3D[y == i]
    cls_C = clss[0:500,:]
    ax.scatter3D(cls_C[:,compA], cls_C[:,compB], cls_C[:,compC])

# %%
import umap

# %%
UMAP_trn_embedding = umap.UMAP(n_neighbors=30,
                      min_dist=1,negative_sample_rate =8,
                      metric='correlation').fit(embs_trn)

UMAP_trn = UMAP_trn_embedding.embedding_
UMAP_val = UMAP_trn_embedding.transform(embs_val)
UMAP_test = UMAP_trn_embedding.transform(embs_test)

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in [2,3,4,0,1,5,6,7,8]:
    trn_UMAP_cls = UMAP_trn[y_trn == i]

    axarr[0].scatter(trn_UMAP_cls[:,compA], trn_UMAP_cls[:,compB], label = data.classes[i], s = 5)
    axarr[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    if i == 2:
        axarr[1].scatter(trn_UMAP_cls[:,compA], trn_UMAP_cls[:,compB], label = data.classes[i], s = 5)

#     axarr[0].set_xlim(-22,15)
#     axarr[0].set_ylim(-15,12)
    
for i in [0,1,2,3]:
    test_UMAP_cls = UMAP_test[y_test == i]
    
    axarr[1].scatter(test_UMAP_cls[:,compA], test_UMAP_cls[:,compB], label = list(lbl2idx_test.keys())[i], s = 5)
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
#     axarr[1].set_xlim(-22,15)
#     axarr[1].set_ylim(-15,12)

# %%
lbl2idx_test

# %%
UMAP_WT = UMAP_trn[y_trn == 2]

# %%
plt.scatter(UMAP_WT[:,0], UMAP_WT[:,1], s = 5)

# %%
len(data.trn_ds.fnames) + len(data.val_ds.fnames)

# %%
# Specify data

x = UMAP_WT[:,0]
y = UMAP_WT[:,1]
data1 = UMAP_WT

with sns.axes_style('white'):
    pal = sns.dark_palette("palegreen", as_cmap=True)
    sns.jointplot(x, y, kind='kde', shade=False, cmap=pal, color='k').plot_joint(plt.scatter, s=18, color='k')
    
#     , xlim=(-1.e3, 1e8), ylim=(-0.2e8, 1e8)

# %%
lbl2idx_test)

# %% [markdown]
# ### Visualizing train and test datasets as exposed by dataloader

# %% [markdown]
# ### Inference

# %%
lbl2idx

# %%
lbl2idx_test

# %%
# test_log_preds, test_targs = learn.predict_with_targs('test')
test_log_preds, test_targs = learn.TTA(is_test=True, n_aug=8)
test_log_preds = np.mean(test_log_preds, axis=0)
testprobs = np.exp(test_log_preds)
test_preds = np.argmax(testprobs, axis=1)

# %%
test_robust = []
y_test_robust = []
for i in [0,1,2]:
    test_robust.extend(test_preds[test_targs == i])
    y_test_robust.extend(test_targs[test_targs==i])

# %%
y_test_robust = np.array(y_test_robust)
y_test_robust[y_test_robust == 2] = 4
y_test_robust[y_test_robust == 1] = 3
y_test_robust[y_test_robust == 0] = 2

# %%
# np.array(test_robust)

cm = confusion_matrix(test_robust,y_test_robust)
plot_confusion_matrix(cm, ['WT', 'mfb1KO', 'mmr1KO'])

# %%
print(accuracy_score(test_robust, y_test_robust))
# print(classification_report(test_robust, y_test_robust, target_names=['WT', 'mfb1KO', 'mmr1KO']))

# %%
preds_dict

# %%
# make predictions dictionary

h = 0
preds_dict = {}
for i, key in enumerate(lbl2idx_test.keys()):
    l = h
    h = h + list(data2.test_dl.dataset.src_idx).count(i)
    preds_dict[key] = list(test_preds[l:h])
    print(f"{key} predictions ready ({h - l} elements)")

# %%
preds_rel = {}
for key in preds_dict.keys():
    print(key)
    val = {cls: preds_dict[key].count(i)/len(preds_dict[key]) for i, cls in enumerate(data2.classes)}
    preds_rel[key]= val

# %%
def plot_test_preds(targets, preds_rel):
    
    if not isinstance(targets, list):
        targets = [targets]
        
    x = math.ceil((int(len(targets)) /2)) # dynamic scaling of GridSpec
    sz = 4 * x # dynamic scaling of figuresize
    
    # plotting:
    plt.figure(figsize=(12,sz))
    gs1 = plt.GridSpec(x,2)
    gs1.update(wspace = 0.4)

    for i, targ in enumerate(targets):
        to_plot = [preds_rel[targ][key] for key in data.classes] # extracting data
        ax1 = plt.subplot(gs1[i])
        ax1.barh(data.classes, to_plot)
        ax1.set_title(targ)
        ax1.set_xlim(0,1)
    
    plt.show()

# %%
test_classes = list(lbl2idx_test.keys())

plot_test_preds(test_classes, preds_rel)
# plot_test_preds(['01_WT', '03_WT', '03_fzo1KO', '01_mfb1KO'], preds_rel)
# plot_test_preds(['01_WT', '01_mfb1KO', '01_mmr1KO'], preds_rel)

# %% [markdown]
# ### Analyse images

# %% [markdown]
# #### Show random correct/incorrectly classified images:

# %%
log_preds_mean = np.mean(log_preds, axis=0) # averages predictions on original + 4 TTA images
preds = np.argmax(log_preds_mean, axis=1) # converts into 0 or 1

# %%
# probs = np.exp(log_preds_mean[:,0]) # prediction(WT)
probs = np.exp(log_preds_mean) # predictions

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, channel, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=11)
        if channel is not None: plt.imshow(ims[i,channel,:,:]) 
        else: plt.imshow(np.sum(ims, axis=1)[i,:,:])

# %%
def plot_val_with_title_from_ds_no_denorm(idxs, title, channel=None):
    
    imgs = np.stack(data.val_ds[x][0] for x in idxs) # get images by idx
    corr_lbl = np.stack(data.val_ds[x][1] for x in idxs) # get correct label from data.val_ds by idx
    pred_lbl = np.stack(preds[x] for x in idxs) # get predicted label from preds by idx
    p_max = [np.amax(probs[x,:]) for x in idxs] # get highest probability from probs by idx
    
    title_fin = [f"true = {corr_lbl[x]}\n predicted: {pred_lbl[x]}\n  p = {p_max[x]}" for x, _ in enumerate(corr_lbl)]
    print(title)
    
    return plots(imgs, channel, rows=1, titles=title_fin, figsize=(16,8))

# %%
lbl2idx_

# %% [markdown]
# ### Plot images according to predictions

# %%
# load from ds - not denormalized! 
plot_val_with_title_from_ds_no_denorm(rand_by_correct(True), "Correctly classified")
#optionally pass channel arg. to select single channel

# %%
plot_val_with_title_from_ds_no_denorm(rand_by_correct(False), "Incorrectly classified")

# %% [markdown]
# #### Show most correct/incorrectly classified images per class:

# %%
def most_by_mask(mask, y, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[:,y][idxs])[0:5]]

def most_by_correct(y, is_correct): 
    mult = -1 if is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), y, mult)

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(0, True), "Most correctly classified WT")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(0, False), "Most incorrectly classified WT") # logic?

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(1, True), "Most correctly classified mfb1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(1, False), "Most incorrectly classified mfb1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(2, True), "Most correctly classified mfb1KO-mmr1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(3, True), "Most correctly classified CK666")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(4, True), "Most correctly classified LatA")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(5, True), "Most correctly classified dnnm1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(6, True), "Most correctly classified fzo1KO")

# %% [markdown]
# #### Show (most) uncertain images

# %%
most_uncertain = t = np.argsort(np.amax(probs, axis = 1))[1:5] # get best "guess" per image and list the least confident ones
plot_val_with_title_from_ds_no_denorm(most_uncertain, "Most uncertain predictions")

# %%
lbl2idx_
