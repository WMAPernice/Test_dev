# %% [markdown]
# ### Importing utilities:

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
import skimage.external.tifffile as tiff

from common import Statistics, dataset_source
from resources.conv_learner import *
from resources.plots import *
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Setting up variables

# %%
PATH = "datasets/HPA_challenge_2018/YNet_data_aws/"
data_path = Path(PATH)

# %%
# CLASSES = ('WT', 'mfb1KO', 'mmr1KO', 'dnm1KO', 'fzo1KO', 'num1KO', 'mmm1KO', 'LatA5uM', 'CK666')
# NUM_CLASSES = len(CLASSES)
BATCH_SIZE = 64
SIZE = [2,224,224]

# %% [markdown]
# #### Calculating normalization statistics
#
# Note that we are setting up train & val data, as well as test. Within test, we are here including a mutant cell type that the model never trains on. The idea is to use to the feature space developed during training to evaluate novel cell types by similarity to the landmarks that the model was trained on.

# %% [markdown]
# ## Defining datasets:

# %%
def tfms_for_test(sz):
    test_norm = Normalize(stats=None, IntNorm=True)
    test_denorm = None
    val_crop = CropType.NO
    test_tfms = image_gen(test_norm, test_denorm,sz, crop_type=val_crop)
    return test_tfms

# %%
def get_data(path: str, sz, bs): # , num_workers=1
    create, lbl2index, lbl2index_test = ImageClassifierData.prepare_from_path(path, val_name='val', bs=bs, num_workers = 8,
                                                                             test_name='test', test_with_labels=True,
                                                                             balance=True)
    augs = [RandomDihedral(),
            RandomRotate(90),
           ]
    
    tfms = tfms_with_IntNorm(sz, aug_tfms=augs, crop_type=CropType.CENTER, pad=sz[1]//8)
    test_tfms = tfms_for_test(sz)
    tfms += (test_tfms, )
    
    return create(tfms), lbl2index, lbl2index_test

# %%
data, lbl2idx, lbl2idx_test = get_data(PATH,SIZE,BATCH_SIZE)
# Out:
# Internal Normalization
# val_crop is: 2
# Internal Normalization
# Using WeightedRandomSampler

# %%
x , y = next(iter(data.trn_dl))

# %%
print(data.test_aug_dl.dataset.transform.tfms)
# Out:
# [<resources.transforms.Scale object at 0x7f895eb985c0>, <resources.transforms.AddPadding object at 0x7f895eb98be0>, <resources.transforms.RandomDihedral object at 0x7f895eb98e80>, <resources.transforms.RandomRotate object at 0x7f895eb981d0>, <resources.transforms.CenterCrop object at 0x7f895eb98fd0>, <resources.transforms.Normalize object at 0x7f895eb98cc0>, <resources.transforms.ChannelOrder object at 0x7f895eb98a20>]

# %% [markdown]
# ### Inspect loaded data:
#
# Displaying the same image with and without normalization.

# %%
# print transformations
plt.style.use('seaborn-white')

c = 0
idx = 0
fig, ax = plt.subplots(2,4, figsize=(16,10))
for i, ax in enumerate(ax.flat):
    x, y = next(iter(data.aug_dl))
    im = to_np(x)[idx]
    ax.imshow(np.sum(im, axis = 0))
#     ax.imshow(im[c])

# %%
# print transformations
plt.style.use('seaborn-white')

c = 1
idx = 0
fig, ax = plt.subplots(2,4, figsize=(16,10))
for i, ax in enumerate(ax.flat):
    x, y = next(iter(data.aug_dl))
    im = to_np(x)[idx]
#     ax.imshow(np.sum(im, axis = 0))
    ax.imshow(im[c])

# %%
def load_epoch(dl = data.trn_dl):
    
    batch = iter(dl)

    xs = []
    ys = []

    for b in range(0,len(dl)):
        x_, y_ = next(batch)
        x_np, y_np = to_np(x_), to_np(y_)
        xs.append(x_np)
        ys.append(y_np)

    return np.vstack(xs), np.concatenate(ys)

# %%
xs, ys =  load_epoch()

# %%
import seaborn as sns

# %%
fig, axarr = plt.subplots(1, 2, figsize=(14, 8))

for i in [2,3]:
    
    xs_clss = xs[ys == i] 
    xs_sub = xs_clss[:100,...]
    xs_sub = xs_sub.reshape(-1,2,50176)
    
    ch0, ch1 = np.ravel(xs_sub[:,0]), np.ravel(xs_sub[:,1])
    print(ch1.shape)

    sns.kdeplot(ch0, ax = axarr[0], label = data.classes[i])
    sns.kdeplot(ch1, ax = axarr[1], label = data.classes[i])
    
# axarr[0].set_xlim(-12,12);
# axarr[1].set_xlim(-10,18);   
# axarr[0].set_ylim(0,0.8);
# axarr[1].set_ylim(0,1.8);
axarr[1].legend()
# Out:
# (5017600,)
# (5017600,)

# %%
print(len(data.val_dl.dataset.y))
print(len(data.trn_dl.dataset.y))
print(len(data.test_dl.dataset.y))

# %% [markdown]
# # Training setup

# %%
torch.cuda.is_available()

# %% [markdown]
# ## ResNet_with_Batchnorm
#
# Defining network architecture.

# %%
arch = resnet18_c
# arch = resnet34_c

# %%
learn = ConvLearner.pretrained(arch, data, ps=0.25, opt_fn=optim.Adam, pretrained=False)

# %%
learn.unfreeze()

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 2, 224, 224]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', True),
#                            ('nb_params', 6272)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-11',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-13',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-14',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-18',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('Conv2d-24',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-25',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-26',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-27',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-34',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-42',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-43',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-44',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-45',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-46',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-47',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-48',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-49',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-50',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1179648)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Conv2d-56',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-57',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-58',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-59',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-66',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-67',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-68',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-69',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-70',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-71',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Dropout-72',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('Linear-73',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 524800)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-75',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-76',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-77',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 8]),
#                            ('trainable', True),
#                            ('nb_params', 4104)])),
#              ('LogSoftmax-78',
#               OrderedDict([('input_shape', [-1, 8]),
#                            ('output_shape', [-1, 8]),
#                            ('nb_params', 0)]))])

# %%
wd=1e-5 # weight-decay/L2 regularization

# %%
learn.lr_find(1e-10)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
# EPOCH 0 ---------------------------------------- STEP 0
# epoch      trn_loss   val_loss   accuracy
#     0      8.670265   3.098643795056795e+18 0.222222
#
# creating log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/

# %%
learn.sched.plot()

# %%
# %time learn.fit(1e-3, 8, cycle_len=1, wds=wd, use_wd_sched=True)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=8, style=ProgressStyle(description_width='initial…
# EPOCH 0 ---------------------------------------- STEP 1
# epoch      trn_loss   val_loss   accuracy
#     0      1.591982   1.613085   0.361905
# EPOCH 1 ---------------------------------------- STEP 2
#     1      1.262489   0.952466   0.607937
# EPOCH 2 ---------------------------------------- STEP 3
#     2      1.051589   0.897384   0.626984
# EPOCH 3 ---------------------------------------- STEP 4
#     3      0.969034   0.889353   0.646032
# EPOCH 4 ---------------------------------------- STEP 5
#     4      0.847996   0.754185   0.688889
# EPOCH 5 ---------------------------------------- STEP 6
#     5      0.74491    0.757213   0.67619
# EPOCH 6 ---------------------------------------- STEP 7
#     6      0.662327   0.828546   0.669841
# EPOCH 7 ---------------------------------------- STEP 8
#     7      0.641163   0.822148   0.653968
#
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# CPU times: user 5min 13s, sys: 43.4 s, total: 5min 57s
# Wall time: 2min 36s
# [array([0.82215]), 0.6539682564281282]

# %%
# %time learn.fit(1e-3, 8, cycle_len=2, wds=wd, use_wd_sched=True, use_clr=(20,8, 0.95, 0.85), best_save_name='YNet_Actin_v1.1_Res18_v1')
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=16, style=ProgressStyle(description_width='initia…
# EPOCH 0 ---------------------------------------- STEP 9
# epoch      trn_loss   val_loss   accuracy
#     0      0.759506   4.385468   0.257143
# EPOCH 1 ---------------------------------------- STEP 10
#     1      0.667975   0.815097   0.650794
# EPOCH 2 ---------------------------------------- STEP 11
#     2      0.606241   3.417212   0.379365
# EPOCH 3 ---------------------------------------- STEP 12
#     3      0.563693   0.573196   0.739683
# EPOCH 4 ---------------------------------------- STEP 13
#     4      0.535015   2.301135   0.450794
# EPOCH 5 ---------------------------------------- STEP 14
#     5      0.518663   0.567684   0.75873
# EPOCH 6 ---------------------------------------- STEP 15
#     6      0.504387   2.085058   0.428571
# EPOCH 7 ---------------------------------------- STEP 16
#     7      0.47345    0.644248   0.728571
# EPOCH 8 ---------------------------------------- STEP 17
#     8      0.483433   1.11185    0.609524
# EPOCH 9 ---------------------------------------- STEP 18
#     9      0.483486   1.049327   0.622222
# EPOCH 10 ---------------------------------------- STEP 19
#     10     0.46228    0.946451   0.642857
# EPOCH 11 ---------------------------------------- STEP 20
#     11     0.433693   0.60455    0.755556
# EPOCH 12 ---------------------------------------- STEP 21
#     12     0.42679    0.595073   0.761905
# EPOCH 13 ---------------------------------------- STEP 22
#     13     0.408854   0.657549   0.730159
# EPOCH 14 ---------------------------------------- STEP 23
#     14     0.443153   4.285649   0.338095
# EPOCH 15 ---------------------------------------- STEP 24
#     15     0.440396   0.580767   0.747619
#
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# CPU times: user 10min 26s, sys: 1min 25s, total: 11min 51s
# Wall time: 5min 13s
# [array([0.58077]), 0.747619048565153]

# %%
learn.load('YNet_Actin_v1.1_Res18_v1')

# %%
# %time learn.fit(1e-3, 3, cycle_len=8, cycle_mult =2, wds=wd, use_wd_sched=True, use_clr=(20,8, 0.95, 0.85), best_save_name='YNet_Actin_v1.1_Res18_v2')
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=56, style=ProgressStyle(description_width='initia…
# EPOCH 0 ---------------------------------------- STEP 25
# epoch      trn_loss   val_loss   accuracy
#     0      0.425488   3.167807   0.298413
# EPOCH 1 ---------------------------------------- STEP 26
#     1      0.521999   3.413396   0.380952
# EPOCH 2 ---------------------------------------- STEP 27
#     2      0.524079   1.144473   0.607937
# EPOCH 3 ---------------------------------------- STEP 28
#     3      0.469526   0.808505   0.701587
# EPOCH 4 ---------------------------------------- STEP 29
#     4      0.443124   0.660782   0.709524
# EPOCH 5 ---------------------------------------- STEP 30
#     5      0.394926   0.499811   0.785714
# EPOCH 6 ---------------------------------------- STEP 31
#     6      0.367213   0.69505    0.714286
# EPOCH 7 ---------------------------------------- STEP 32
#     7      0.336556   0.545349   0.75873
# EPOCH 8 ---------------------------------------- STEP 33
#     8      0.330894   0.873589   0.674603
# EPOCH 9 ---------------------------------------- STEP 34
#     9      0.404929   1.695347   0.488889
# EPOCH 10 ---------------------------------------- STEP 35
#     10     0.429477   0.757833   0.688889
# EPOCH 11 ---------------------------------------- STEP 36
#     11     0.401502   1.020027   0.660317
# EPOCH 12 ---------------------------------------- STEP 37
#     12     0.391042   0.642152   0.739683
# EPOCH 13 ---------------------------------------- STEP 38
#     13     0.359242   0.444694   0.812698
# EPOCH 14 ---------------------------------------- STEP 39
#     14     0.339392   0.443256   0.801587
# EPOCH 15 ---------------------------------------- STEP 40
#     15     0.318076   0.412756   0.820635
# EPOCH 16 ---------------------------------------- STEP 41
#     16     0.312297   0.778582   0.725397
# EPOCH 17 ---------------------------------------- STEP 42
#     17     0.360229   1.215737   0.596825
# EPOCH 18 ---------------------------------------- STEP 43
#     18     0.364376   0.852419   0.692063
# EPOCH 19 ---------------------------------------- STEP 44
#     19     0.340899   0.572265   0.798413
# EPOCH 20 ---------------------------------------- STEP 45
#     20     0.333121   1.003811   0.650794
# EPOCH 21 ---------------------------------------- STEP 46
#     21     0.330145   0.547223   0.790476
# EPOCH 22 ---------------------------------------- STEP 47
#     22     0.303201   0.414955   0.822222
# EPOCH 23 ---------------------------------------- STEP 48
#     23     0.287559   0.401408   0.834921
# EPOCH 24 ---------------------------------------- STEP 49
#     24     0.27475    1.986926   0.588889
# EPOCH 25 ---------------------------------------- STEP 50
#     25     0.300056   0.755636   0.704762
# EPOCH 26 ---------------------------------------- STEP 51
#     26     0.314068   1.179419   0.634921
# EPOCH 27 ---------------------------------------- STEP 52
#     27     0.315482   0.538935   0.787302
# EPOCH 28 ---------------------------------------- STEP 53
#     28     0.317374   0.655961   0.753968
# EPOCH 29 ---------------------------------------- STEP 54
#     29     0.293978   0.48691    0.790476
# EPOCH 30 ---------------------------------------- STEP 55
#     30     0.276183   0.466473   0.804762
# EPOCH 31 ---------------------------------------- STEP 56
#     31     0.257675   0.394208   0.830159
# EPOCH 32 ---------------------------------------- STEP 57
#     32     0.257441   1.84192    0.546032
# EPOCH 33 ---------------------------------------- STEP 58
#     33     0.303446   1.235075   0.688889
# EPOCH 34 ---------------------------------------- STEP 59
#     34     0.311569   1.296191   0.57619
# EPOCH 35 ---------------------------------------- STEP 60
#     35     0.297715   0.672016   0.746032
# EPOCH 36 ---------------------------------------- STEP 61
#     36     0.280366   0.528651   0.796825
# EPOCH 37 ---------------------------------------- STEP 62
#     37     0.271324   0.501729   0.811111
# EPOCH 38 ---------------------------------------- STEP 63
#     38     0.258086   0.476728   0.815873
# EPOCH 39 ---------------------------------------- STEP 64
#     39     0.251657   0.398984   0.839683
# EPOCH 40 ---------------------------------------- STEP 65
#     40     0.24707    1.082092   0.715873
# EPOCH 41 ---------------------------------------- STEP 66
#     41     0.272021   1.743522   0.496825
# EPOCH 42 ---------------------------------------- STEP 67
#     42     0.284953   1.46893    0.603175
# EPOCH 43 ---------------------------------------- STEP 68
#     43     0.274213   0.54975    0.793651
# EPOCH 44 ---------------------------------------- STEP 69
#     44     0.27003    0.948975   0.712698
# EPOCH 45 ---------------------------------------- STEP 70
#     45     0.257963   0.491611   0.820635
# EPOCH 46 ---------------------------------------- STEP 71
#     46     0.246351   0.397496   0.849206
# EPOCH 47 ---------------------------------------- STEP 72
#     47     0.232804   0.368469   0.865079
# EPOCH 48 ---------------------------------------- STEP 73
#     48     0.223273   0.663853   0.766667
# EPOCH 49 ---------------------------------------- STEP 74
#     49     0.250147   1.556308   0.584127
# EPOCH 50 ---------------------------------------- STEP 75
#     50     0.256727   0.825686   0.728571
# EPOCH 51 ---------------------------------------- STEP 76
#     51     0.25593    0.865226   0.701587
# EPOCH 52 ---------------------------------------- STEP 77
#     52     0.251146   0.521318   0.804762
# EPOCH 53 ---------------------------------------- STEP 78
#     53     0.231521   0.439473   0.844444
# EPOCH 54 ---------------------------------------- STEP 79
#     54     0.216593   0.403367   0.846032
# EPOCH 55 ---------------------------------------- STEP 80
#     55     0.193432   0.396071   0.850794
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# CPU times: user 36min 33s, sys: 5min 1s, total: 41min 34s
# Wall time: 18min 17s
# [array([0.39607]), 0.8507936507936508]

# %%
# %time learn.fit(5e-4, 3, cycle_len=16, cycle_mult =2, wds=wd, use_wd_sched=True, use_clr=(20,8, 0.95, 0.85), best_save_name='YNet_Actin_v1.1_Res18_v3')
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=112, style=ProgressStyle(description_width='initi…
# EPOCH 0 ---------------------------------------- STEP 81
# epoch      trn_loss   val_loss   accuracy
#     0      0.173447   0.411607   0.846032
# EPOCH 1 ---------------------------------------- STEP 82
#     1      0.187627   0.545482   0.8
# EPOCH 2 ---------------------------------------- STEP 83
#     2      0.194754   0.477287   0.815873
# EPOCH 3 ---------------------------------------- STEP 84
#     3      0.210491   0.460023   0.84127
# EPOCH 4 ---------------------------------------- STEP 85
#     4      0.209961   0.613099   0.777778
# EPOCH 5 ---------------------------------------- STEP 86
#     5      0.196864   0.393389   0.850794
# EPOCH 6 ---------------------------------------- STEP 87
#     6      0.185361   0.464276   0.838095
# EPOCH 7 ---------------------------------------- STEP 88
#     7      0.183212   0.388967   0.846032
# EPOCH 8 ---------------------------------------- STEP 89
#     8      0.181328   0.6872     0.793651
# EPOCH 9 ---------------------------------------- STEP 90
#     9      0.174497   0.688793   0.787302
# EPOCH 10 ---------------------------------------- STEP 91
#     10     0.170593   0.702526   0.77619
# EPOCH 11 ---------------------------------------- STEP 92
#     11     0.166816   0.447188   0.844444
# EPOCH 12 ---------------------------------------- STEP 93
#     12     0.15763    0.45402    0.828571
# EPOCH 13 ---------------------------------------- STEP 94
#     13     0.152879   0.412859   0.861905
# EPOCH 14 ---------------------------------------- STEP 95
#     14     0.149016   0.382971   0.857143
# EPOCH 15 ---------------------------------------- STEP 96
#     15     0.146974   0.370265   0.865079
# EPOCH 16 ---------------------------------------- STEP 97
#     16     0.138071   0.39855    0.855556
# EPOCH 17 ---------------------------------------- STEP 98
#     17     0.140877   1.145501   0.719048
# EPOCH 18 ---------------------------------------- STEP 99
#     18     0.171797   0.521838   0.822222
# EPOCH 19 ---------------------------------------- STEP 100
#     19     0.183584   0.5333     0.809524
# EPOCH 20 ---------------------------------------- STEP 101
#     20     0.187687   1.836353   0.595238
# EPOCH 21 ---------------------------------------- STEP 102
#     21     0.17864    0.517531   0.806349
# EPOCH 22 ---------------------------------------- STEP 103
#     22     0.16836    0.579166   0.812698
# EPOCH 23 ---------------------------------------- STEP 104
#     23     0.171834   0.613143   0.815873
# EPOCH 24 ---------------------------------------- STEP 105
#     24     0.158382   0.602422   0.803175
# EPOCH 25 ---------------------------------------- STEP 106
#     25     0.146053   0.451738   0.855556
# EPOCH 26 ---------------------------------------- STEP 107
#     26     0.142676   0.451994   0.836508
# EPOCH 27 ---------------------------------------- STEP 108
#     27     0.138375   0.440085   0.852381
# EPOCH 28 ---------------------------------------- STEP 109
#     28     0.136584   0.409715   0.865079
# EPOCH 29 ---------------------------------------- STEP 110
#     29     0.129582   0.391759   0.868254
# EPOCH 30 ---------------------------------------- STEP 111
#     30     0.124829   0.41536    0.855556
# EPOCH 31 ---------------------------------------- STEP 112
#     31     0.117576   0.399276   0.869841
# EPOCH 32 ---------------------------------------- STEP 113
#     32     0.115292   0.446974   0.849206
# EPOCH 33 ---------------------------------------- STEP 114
#     33     0.117465   0.874999   0.755556
# EPOCH 34 ---------------------------------------- STEP 115
#     34     0.131507   0.8881     0.752381
# EPOCH 35 ---------------------------------------- STEP 116
#     35     0.141212   0.56818    0.81746
# EPOCH 36 ---------------------------------------- STEP 117
#     36     0.158589   0.476291   0.844444
# EPOCH 37 ---------------------------------------- STEP 118
#     37     0.169359   0.622226   0.8
# EPOCH 38 ---------------------------------------- STEP 119
#     38     0.160678   0.53638    0.825397
# EPOCH 39 ---------------------------------------- STEP 120
#     39     0.142884   0.565304   0.81746
# EPOCH 40 ---------------------------------------- STEP 121
#     40     0.129019   0.563819   0.833333
# EPOCH 41 ---------------------------------------- STEP 122
#     41     0.121764   0.419172   0.865079
# EPOCH 42 ---------------------------------------- STEP 123
#     42     0.122514   0.530388   0.836508
# EPOCH 43 ---------------------------------------- STEP 124
#     43     0.114216   0.443121   0.857143
# EPOCH 44 ---------------------------------------- STEP 125
#     44     0.111468   0.406026   0.871429
# EPOCH 45 ---------------------------------------- STEP 126
#     45     0.104265   0.438928   0.853968
# EPOCH 46 ---------------------------------------- STEP 127
#     46     0.099332   0.407224   0.873016
# EPOCH 47 ---------------------------------------- STEP 128
#     47     0.098638   0.390586   0.871429
# EPOCH 48 ---------------------------------------- STEP 129
#     48     0.089092   0.397299   0.868254
# EPOCH 49 ---------------------------------------- STEP 130
#     49     0.104002   0.651793   0.806349
# EPOCH 50 ---------------------------------------- STEP 131
#     50     0.149266   2.500407   0.584127
# EPOCH 51 ---------------------------------------- STEP 132
#     51     0.162868   0.530686   0.838095
# EPOCH 52 ---------------------------------------- STEP 133
#     52     0.156344   0.784433   0.788889
# EPOCH 53 ---------------------------------------- STEP 134
#     53     0.150159   0.654533   0.790476
# EPOCH 54 ---------------------------------------- STEP 135
#     54     0.144205   0.399658   0.869841
# EPOCH 55 ---------------------------------------- STEP 136
#     55     0.143705   0.514305   0.822222
# EPOCH 56 ---------------------------------------- STEP 137
#     56     0.139776   0.473598   0.85873
# EPOCH 57 ---------------------------------------- STEP 138
#     57     0.12919    0.516047   0.836508
# EPOCH 58 ---------------------------------------- STEP 139
#     58     0.123489   0.47196    0.839683
# EPOCH 59 ---------------------------------------- STEP 140
#     59     0.122195   0.413047   0.868254
# EPOCH 60 ---------------------------------------- STEP 141
#     60     0.104773   0.431658   0.850794
# EPOCH 61 ---------------------------------------- STEP 142
#     61     0.095623   0.382711   0.87619
# EPOCH 62 ---------------------------------------- STEP 143
#     62     0.093865   0.424762   0.861905
# EPOCH 63 ---------------------------------------- STEP 144
#     63     0.092331   0.379131   0.877778
# EPOCH 64 ---------------------------------------- STEP 145
#     64     0.083854   0.403355   0.861905
# EPOCH 65 ---------------------------------------- STEP 146
#     65     0.085589   0.638106   0.819048
# EPOCH 66 ---------------------------------------- STEP 147
#     66     0.112894   1.063579   0.774603
# EPOCH 67 ---------------------------------------- STEP 148
#     67     0.125032   0.542207   0.825397
# EPOCH 68 ---------------------------------------- STEP 149
#     68     0.136731   0.458345   0.846032
# EPOCH 69 ---------------------------------------- STEP 150
#     69     0.135262   0.53407    0.844444
# EPOCH 70 ---------------------------------------- STEP 151
#     70     0.121847   0.439142   0.842857
# EPOCH 71 ---------------------------------------- STEP 152
#     71     0.113395   0.549611   0.846032
# EPOCH 72 ---------------------------------------- STEP 153
#     72     0.108391   0.455654   0.868254
# EPOCH 73 ---------------------------------------- STEP 154
#     73     0.100715   0.455508   0.868254
# EPOCH 74 ---------------------------------------- STEP 155
#     74     0.08965    0.480903   0.847619
# EPOCH 75 ---------------------------------------- STEP 156
#     75     0.09       0.467115   0.855556
# EPOCH 76 ---------------------------------------- STEP 157
#     76     0.079327   0.422527   0.868254
# EPOCH 77 ---------------------------------------- STEP 158
#     77     0.078867   0.425825   0.87619
# EPOCH 78 ---------------------------------------- STEP 159
#     78     0.078406   0.450294   0.865079
# EPOCH 79 ---------------------------------------- STEP 160
#     79     0.076522   0.394603   0.873016
# EPOCH 80 ---------------------------------------- STEP 161
#     80     0.069833   0.445891   0.857143
# EPOCH 81 ---------------------------------------- STEP 162
#     81     0.078758   0.751568   0.796825
# EPOCH 82 ---------------------------------------- STEP 163
#     82     0.104517   0.739878   0.828571
# EPOCH 83 ---------------------------------------- STEP 164
#     83     0.11618    1.177158   0.715873
# EPOCH 84 ---------------------------------------- STEP 165
#     84     0.129461   0.430952   0.866667
# EPOCH 85 ---------------------------------------- STEP 166
#     85     0.123917   1.350288   0.696825
# EPOCH 86 ---------------------------------------- STEP 167
#     86     0.114389   0.533901   0.820635
# EPOCH 87 ---------------------------------------- STEP 168
#     87     0.105718   0.600796   0.839683
# EPOCH 88 ---------------------------------------- STEP 169
#     88     0.103009   0.41121    0.868254
# EPOCH 89 ---------------------------------------- STEP 170
#     89     0.091187   0.463337   0.85873
# EPOCH 90 ---------------------------------------- STEP 171
#     90     0.082955   0.505407   0.857143
# EPOCH 91 ---------------------------------------- STEP 172
#     91     0.083371   0.46729    0.861905
# EPOCH 92 ---------------------------------------- STEP 173
#     92     0.082195   0.436048   0.865079
# EPOCH 93 ---------------------------------------- STEP 174
#     93     0.072966   0.398835   0.873016
# EPOCH 94 ---------------------------------------- STEP 175
#     94     0.068741   0.41599    0.874603
# EPOCH 95 ---------------------------------------- STEP 176
#     95     0.060938   0.446594   0.869841
# EPOCH 96 ---------------------------------------- STEP 177
#     96     0.059728   0.472206   0.868254
# EPOCH 97 ---------------------------------------- STEP 178
#     97     0.06374    0.77592    0.785714
# EPOCH 98 ---------------------------------------- STEP 179
#     98     0.082561   1.267545   0.712698
# EPOCH 99 ---------------------------------------- STEP 180
#     99     0.085107   0.596787   0.830159
# EPOCH 100 ---------------------------------------- STEP 181
#    100     0.083908   0.563398   0.857143
# EPOCH 101 ---------------------------------------- STEP 182
#    101     0.073772   0.484067   0.866667
# EPOCH 102 ---------------------------------------- STEP 183
#    102     0.074533   0.409707   0.860317
# EPOCH 103 ---------------------------------------- STEP 184
#    103     0.079304   0.64797    0.830159
# EPOCH 104 ---------------------------------------- STEP 185
#    104     0.077191   0.471712   0.871429
# EPOCH 105 ---------------------------------------- STEP 186
#    105     0.076803   0.523822   0.866667
# EPOCH 106 ---------------------------------------- STEP 187
#    106     0.075005   0.570497   0.852381
# EPOCH 107 ---------------------------------------- STEP 188
#    107     0.067864   0.521121   0.850794
# EPOCH 108 ---------------------------------------- STEP 189
#    108     0.065822   0.469567   0.861905
# EPOCH 109 ---------------------------------------- STEP 190
#    109     0.058327   0.463924   0.85873
# EPOCH 110 ---------------------------------------- STEP 191
#    110     0.052869   0.418229   0.87619
# EPOCH 111 ---------------------------------------- STEP 192
#    111     0.048056   0.441951   0.869841
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# appending existing log-files...
# log-files saved to: datasets/HPA_challenge_2018/YNet_data_aws/
# CPU times: user 1h 13min 11s, sys: 10min 1s, total: 1h 23min 12s
# Wall time: 36min 36s
# [array([0.44195]), 0.8698412698412699]

# %%
f = plt.figure()
x = learn.sched.plot_loss()
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.show()

# %%
learn.sched.plot_lr()

# %%
# %time learn.fit(4e-3, 2, cycle_len=8, wds=wd, use_wd_sched=True)

# %%
learn.save('yeast_v11.3_ResNet18_82_v1')

# %%
learn.load('YNet_Actin_v1.1_Res18_v3')

# %% [markdown]
# #### Run some more cylces - error & accuracy should continuously improve
#
# Note: cycle len = number of epochs per cycle

# %%
learn.freeze_to(2)

# %%
adjust = {0:22,
          1:14,
#           2:22,
          3:3,
          4:3,
         5:14,
         6:14
         }

# use_clr=(20,8, 0.95, 0.85),
# %time learn.fit(1e-3, 1, cycle_len=8, wds=wd, use_wd_sched=True, adjust_class=adjust, best_save_name='YNet_v11.1_ResNet34_dihedral_ps025_IntNorm_rot90_rGauss_balanced_86_FT_mmr1')

# %% [markdown]
# ## Analysis/Model evaluation
#
# This is one of the major areas that needs improvement in our workflow. The tools we have so far (confusion matrix and manual inpsection of images) are essential but definitely not sufficient to ensure that our model learns something biologicaly relevant. Ideas are welcome!

# %% [markdown]
# ### ...after training

# %%
## Load model:
learn.load('YNet_Actin_v1.1_Res18_v3')
learn.freeze_to(3)

# %%
log_preds, y = learn.TTA(8) # run predictions with TTA

# %% [markdown]
# ### Cross_validation evaluation

# %%
# Plot confusion matrix 
plt.style.use('seaborn-white')
log_preds_mean = np.mean(log_preds, axis=0)
preds = np.argmax(log_preds_mean, axis=1)
cm = confusion_matrix(preds,y)
plot_confusion_matrix(cm, data.classes)
# Out:
# [[ 63   6   0   0   0   0   0   0]
#  [  5  61   0   0   0   0   0   0]
#  [  1   0 117   5   0   8   0   0]
#  [  1   0   9  51   0   9   0   0]
#  [  0   1   0   0  70   0   0   0]
#  [  0   1  14  14   0  53   0   0]
#  [  0   1   0   0   0   0  69   0]
#  [  0   0   0   0   0   0   1  70]]

# %%
# targ_names = ['mmm1KO', 'num1KO', 'WT', 'mfb1KO', 'mmr1KO', 'CK666', 'LatA', 'dnm1KO', 'fzo1KO']

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(accuracy_score(preds, y))

print(classification_report(preds, y, target_names=data.classes))
# Out:
# 0.8793650793650793
#                precision    recall  f1-score   support
#
#        mmm1KO       0.90      0.91      0.91        69
#        num1KO       0.87      0.92      0.90        66
#            WT       0.84      0.89      0.86       131
#        mfb1KO       0.73      0.73      0.73        70
#        mmr1KO       1.00      0.99      0.99        71
# mmr1KO-mfb1KO       0.76      0.65      0.70        82
#         CK666       0.99      0.99      0.99        70
#      LatA-5uM       1.00      0.99      0.99        71
#
#     micro avg       0.88      0.88      0.88       630
#     macro avg       0.88      0.88      0.88       630
#  weighted avg       0.88      0.88      0.88       630

# %%
preds_noAct = []
y_noAct = []
for i in [2,3,4,0,1,7,8]:
    preds_noAct.extend(preds[y == i])
    y_noAct.extend(y[y==i])
    
print(accuracy_score(preds_noAct, y_noAct))
print(classification_report(preds_noAct, y_noAct, target_names=['WT', 'mfb1KO', 'mmr1KO', 'mmm1KO', 'num1KO', 'dnm1KO', 'fzo1KO']))

# %%
len(y_noAct), len(preds_noAct)

# %% [markdown]
# ## Test-set eval

# %%
learn.models.model

# %%
# function to be called by register_forward_hook

def get_embeddings(layer_name):
    def register_hook(layer_name):
        def get_embedding(layer, inp, outp):
            tmp = inp[0]
            embedding.append(tmp)

        hook = layer.register_forward_hook(get_embedding) 
        
        for i in ['trn', 'val', 'test']:
            embedding = []
            preds, y = learn.predict_with_targs(i)
            
            # populating dict, consiting of [0]: preds, [1]: y, [2]: activations[layer]
            embeddings[i] = [preds, y, np.vstack(to_np(embedding))]
            
        hook.remove()
        
    embeddings = {}    
    layer = learn.models.model._modules.get(layer_name)
    register_hook(layer)
    
    return embeddings

# %%
embeddings = get_embeddings('14')

# %%
# unpacking embeddings

embs_trn = embeddings['trn'][2]
y_trn = embeddings['trn'][1]

embs_val = embeddings['val'][2]
y_val = embeddings['val'][1]

embs_test = embeddings['test'][2]
y_test = embeddings['test'][1]

print(embs_trn.shape)
print(embs_val.shape)
print(embs_test.shape)

print(y_trn.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1884, 512)
# (630, 512)
# (2025, 512)
# (1884,)
# (630,)
# (2025,)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
# running PCA on embeddings
pca = []
n_components = 50
pca = PCA(n_components)

trn_pca_result = pca.fit_transform(embs_trn)
val_pca_result = pca.transform(embs_val)
test_pca_result = pca.transform(embs_test)

# %%
#plotting compenent-wise cumulative explained variance (for PCA)

plt.plot(range(n_components), pca.explained_variance_ratio_)
plt.plot(range(n_components), np.cumsum(pca.explained_variance_ratio_))
plt.title("Component-wise and Cumulative Explained Variance")

# %%
# running TSNE on embeddings

tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(embs_trn)

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in range(9):
    PCA_cls = trn_pca_result[y_trn == i]
    TSNE_cls = tsne_results[y_trn == i]
    
    axarr[0].scatter(PCA_cls[:,compA], PCA_cls[:,compB], label = data.classes[i], s = 5)
    axarr[1].scatter(TSNE_cls[:,compA], TSNE_cls[:,compB], label = data.classes[i], s =5)
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in range(7):
    trn_PCA_cls = trn_pca_result[y_trn == i]
    val_PCA_cls = val_pca_result[y_val == i]

    axarr[0].scatter(trn_PCA_cls[:,compA], trn_PCA_cls[:,compB], label = data.classes[i])
    axarr[1].scatter(val_PCA_cls[:,compA], val_PCA_cls[:,compB], label = data.classes[i])
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
print(lbl2idx_test)

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in range(7):
    trn_PCA_cls = trn_pca_result[y_trn == i]

    axarr[0].scatter(trn_PCA_cls[:,compA], trn_PCA_cls[:,compB], label = data.classes[i])
    axarr[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    axarr[0].set_xlim(-15,45)
    axarr[0].set_ylim(-20,20)
    
for i in [0,1,3]:
    test_PCA_cls = test_pca_result[y_test == i]
    axarr[1].scatter(test_PCA_cls[:,compA], test_PCA_cls[:,compB], label = list(lbl2idx_test.keys())[i])
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    axarr[1].set_xlim(-15,45)
    axarr[1].set_ylim(-20,20)

# %%
list(lbl2idx_test.keys())[0]

# %%
# Generate 3D TSNE space from PCA of embeddings

tsne3D = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300, learning_rate=50.0)
PCA2tSNE_results_3D = tsne3D.fit_transform(embs)

# %%
tsne3D

# %%
from mpl_toolkits import mplot3d

# magic command to make plots interactive.
# restart kernel if you want to switch to e.g. %matplotlib inline
# %matplotlib notebook

# %%
# 3D plotting - very slow interactivity atm...

fig = plt.figure()
ax = plt.axes(projection='3d')

compA = 0
compB = 1
compC = 2

for i in range(10):
    clss = PCA2tSNE_results_3D[y == i]
    cls_C = clss[0:500,:]
    ax.scatter3D(cls_C[:,compA], cls_C[:,compB], cls_C[:,compC])

# %%
import umap

# %%
UMAP_trn_embedding = umap.UMAP(n_neighbors=30,
                      min_dist=1,
                      metric='correlation').fit(embs_trn)

UMAP_trn = UMAP_trn_embedding.embedding_
UMAP_val = UMAP_trn_embedding.transform(embs_val)
UMAP_test = UMAP_trn_embedding.transform(embs_test)

# %%
lbl2idx
# Out:
# {'01_mmm1KO': [0, 0, 'mmm1KO'],
#  '01_num1KO': [1, 1, 'num1KO'],
#  '02_WT': [2, 2, 'WT'],
#  '02_mfb1KO': [3, 3, 'mfb1KO'],
#  '02_mmr1KO': [4, 4, 'mmr1KO'],
#  '02_mmr1KO-mfb1KO': [5, 5, 'mmr1KO-mfb1KO'],
#  '03_CK666': [6, 6, 'CK666'],
#  '03_LatA-5uM': [7, 7, 'LatA-5uM'],
#  '03_WT': [8, 2, 'WT']}

# %%
# plotting PCA vs TSNE results

fig, axarr = plt.subplots(1, 2, figsize=(20, 8))

compA = 0
compB = 1

for i in [2,3,4,5,0,1,6,7]:
    trn_UMAP_cls = UMAP_trn[y_trn == i]

    axarr[0].scatter(trn_UMAP_cls[:,compA], trn_UMAP_cls[:,compB], label = data.classes[i], s = 5)
    axarr[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    if i == 2:
        axarr[1].scatter(trn_UMAP_cls[:,compA], trn_UMAP_cls[:,compB], label = data.classes[i], s = 5)
    if i == 6:
        axarr[1].scatter(trn_UMAP_cls[:,compA], trn_UMAP_cls[:,compB], label = data.classes[i], s = 5, c='gray')

    axarr[0].set_xlim(-22,20)
    axarr[0].set_ylim(-30,30)
    
for i in [7]:
    test_UMAP_cls = UMAP_test[y_test == i]
    
    axarr[1].scatter(test_UMAP_cls[:,compA], test_UMAP_cls[:,compB], label = list(lbl2idx_test.keys())[i], s = 5)
    axarr[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    axarr[1].set_xlim(-22,20)
    axarr[1].set_ylim(-30,30)

# %%
lbl2idx_test
# Out:
# {'01_WT': [0, 0, 'WT'],
#  '01_mfb1KO': [1, 1, 'mfb1KO'],
#  '01_mmr1KO': [2, 2, 'mmr1KO'],
#  '03_DMSO': [3, 3, 'DMSO'],
#  '03_Eth': [4, 4, 'Eth'],
#  '03_LatA-05uM': [5, 5, 'LatA-05uM'],
#  '03_axl1KO': [6, 6, 'axl1KO'],
#  '03_bud1KO': [7, 7, 'bud1KO']}

# %%
UMAP_WT = UMAP_trn[y_trn == 2]

# %%
plt.scatter(UMAP_WT[:,0], UMAP_WT[:,1], s = 5)

# %%
len(data.trn_ds.fnames) + len(data.val_ds.fnames)

# %%
# Specify data

x = UMAP_WT[:,0]
y = UMAP_WT[:,1]
data1 = UMAP_WT

with sns.axes_style('white'):
    pal = sns.dark_palette("palegreen", as_cmap=True)
    sns.jointplot(x, y, kind='kde', shade=False, cmap=pal, color='k').plot_joint(plt.scatter, s=18, color='k')
    
#     , xlim=(-1.e3, 1e8), ylim=(-0.2e8, 1e8)

# %%
lbl2idx_test)

# %% [markdown]
# ### Visualizing train and test datasets as exposed by dataloader

# %% [markdown]
# ### Inference

# %%
lbl2idx

# %%
lbl2idx_test

# %%
# test_log_preds, test_targs = learn.predict_with_targs('test')
test_log_preds, test_targs = learn.TTA(is_test=True, n_aug=8)
test_log_preds = np.mean(test_log_preds, axis=0)
testprobs = np.exp(test_log_preds)
test_preds = np.argmax(testprobs, axis=1)

# %%
test_robust = []
y_test_robust = []
for i in [0,1,2]:
    test_robust.extend(test_preds[test_targs == i])
    y_test_robust.extend(test_targs[test_targs==i])

# %%
y_test_robust = np.array(y_test_robust)
y_test_robust[y_test_robust == 2] = 4
y_test_robust[y_test_robust == 1] = 3
y_test_robust[y_test_robust == 0] = 2

# %%
# np.array(test_robust)

cm = confusion_matrix(test_robust,y_test_robust)
plot_confusion_matrix(cm, ['WT', 'mfb1KO', 'mmr1KO'])

# %%
print(accuracy_score(test_robust, y_test_robust))
# print(classification_report(test_robust, y_test_robust, target_names=['WT', 'mfb1KO', 'mmr1KO']))

# %%
preds_dict

# %%
# make predictions dictionary

h = 0
preds_dict = {}
for i, key in enumerate(lbl2idx_test.keys()):
    l = h
    h = h + list(data2.test_dl.dataset.src_idx).count(i)
    preds_dict[key] = list(test_preds[l:h])
    print(f"{key} predictions ready ({h - l} elements)")

# %%
preds_rel = {}
for key in preds_dict.keys():
    print(key)
    val = {cls: preds_dict[key].count(i)/len(preds_dict[key]) for i, cls in enumerate(data2.classes)}
    preds_rel[key]= val

# %%
def plot_test_preds(targets, preds_rel):
    
    if not isinstance(targets, list):
        targets = [targets]
        
    x = math.ceil((int(len(targets)) /2)) # dynamic scaling of GridSpec
    sz = 4 * x # dynamic scaling of figuresize
    
    # plotting:
    plt.figure(figsize=(12,sz))
    gs1 = plt.GridSpec(x,2)
    gs1.update(wspace = 0.4)

    for i, targ in enumerate(targets):
        to_plot = [preds_rel[targ][key] for key in data.classes] # extracting data
        ax1 = plt.subplot(gs1[i])
        ax1.barh(data.classes, to_plot)
        ax1.set_title(targ)
        ax1.set_xlim(0,1)
    
    plt.show()

# %%
test_classes = list(lbl2idx_test.keys())

plot_test_preds(test_classes, preds_rel)
# plot_test_preds(['01_WT', '03_WT', '03_fzo1KO', '01_mfb1KO'], preds_rel)
# plot_test_preds(['01_WT', '01_mfb1KO', '01_mmr1KO'], preds_rel)

# %% [markdown]
# ### Analyse images

# %% [markdown]
# #### Show random correct/incorrectly classified images:

# %%
log_preds_mean = np.mean(log_preds, axis=0) # averages predictions on original + 4 TTA images
preds = np.argmax(log_preds_mean, axis=1) # converts into 0 or 1

# %%
# probs = np.exp(log_preds_mean[:,0]) # prediction(WT)
probs = np.exp(log_preds_mean) # predictions

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, channel, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=11)
        if channel is not None: plt.imshow(ims[i,channel,:,:]) 
        else: plt.imshow(np.sum(ims, axis=1)[i,:,:])

# %%
def plot_val_with_title_from_ds_no_denorm(idxs, title, channel=None):
    
    imgs = np.stack(data.val_ds[x][0] for x in idxs) # get images by idx
    corr_lbl = np.stack(data.val_ds[x][1] for x in idxs) # get correct label from data.val_ds by idx
    pred_lbl = np.stack(preds[x] for x in idxs) # get predicted label from preds by idx
    p_max = [np.amax(probs[x,:]) for x in idxs] # get highest probability from probs by idx
    
    title_fin = [f"true = {corr_lbl[x]}\n predicted: {pred_lbl[x]}\n  p = {p_max[x]}" for x, _ in enumerate(corr_lbl)]
    print(title)
    
    return plots(imgs, channel, rows=1, titles=title_fin, figsize=(16,8))

# %%
lbl2idx_

# %% [markdown]
# ### Plot images according to predictions

# %%
# load from ds - not denormalized! 
plot_val_with_title_from_ds_no_denorm(rand_by_correct(True), "Correctly classified")
#optionally pass channel arg. to select single channel

# %%
plot_val_with_title_from_ds_no_denorm(rand_by_correct(False), "Incorrectly classified")

# %% [markdown]
# #### Show most correct/incorrectly classified images per class:

# %%
def most_by_mask(mask, y, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[:,y][idxs])[0:5]]

def most_by_correct(y, is_correct): 
    mult = -1 if is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), y, mult)

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(0, True), "Most correctly classified WT")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(0, False), "Most incorrectly classified WT") # logic?

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(1, True), "Most correctly classified mfb1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(1, False), "Most incorrectly classified mfb1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(2, True), "Most correctly classified mfb1KO-mmr1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(3, True), "Most correctly classified CK666")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(4, True), "Most correctly classified LatA")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(5, True), "Most correctly classified dnnm1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(6, True), "Most correctly classified fzo1KO")

# %% [markdown]
# #### Show (most) uncertain images

# %%
most_uncertain = t = np.argsort(np.amax(probs, axis = 1))[1:5] # get best "guess" per image and list the least confident ones
plot_val_with_title_from_ds_no_denorm(most_uncertain, "Most uncertain predictions")

# %%
lbl2idx_
