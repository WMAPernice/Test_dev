# %% [markdown]
# # YNet_data_03 Mito
#
# Data from Experiment (2), Mitochondria = Cit1-mCherry

# %% [markdown]
# ### Importing utilities:

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
import skimage.external.tifffile as tiff

from common import Statistics, dataset_source
from resources.conv_learner import *
from resources.plots import *
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Setting up variables

# %%
PATH = "datasets/yeast_v5/"
data_path = Path(PATH)

# %%
CLASSES = ('WT', 'mfb1KO', 'mfb1KO_mmr1KO', 'mmr1KO', 'mmm1KO', 'num1KO')
NUM_CLASSES = len(CLASSES)
BATCH_SIZE = 64
SIZE = 200

# %% [markdown]
# #### Calculating normalization statistics
#
# Note that we are setting up train & val data, as well as test. Within test, we are here including a mutant cell type that the model never trains on. The idea is to use to the feature space developed during training to evaluate novel cell types by similarity to the landmarks that the model was trained on.

# %%
stats_name = "yeast_v5_per_class.dict"
classes = Statistics.source_class(data_path)

train_val = zip(classes['train'], classes['val'])
# Xtest = zip(classes['test'])
 
main_stats = Statistics.per_class(train_val, save_name=stats_name)
# test_stats = Statistics.per_class(Xtest, save_name=stats_name)
# Out:
# working on: datasets\yeast_v5\train\mfb1KO
# working on: datasets\yeast_v5\val\mfb1KO
# working on: datasets\yeast_v5\train\mfb1KO_mmr1KO
# working on: datasets\yeast_v5\val\mfb1KO_mmr1KO
# working on: datasets\yeast_v5\train\mmm1KO
# working on: datasets\yeast_v5\val\mmm1KO
# working on: datasets\yeast_v5\train\mmr1KO
# working on: datasets\yeast_v5\val\mmr1KO
# working on: datasets\yeast_v5\train\num1KO
# working on: datasets\yeast_v5\val\num1KO
# working on: datasets\yeast_v5\train\WT
# working on: datasets\yeast_v5\val\WT

# %%
for keys in main_stats.keys():
    print(f"{keys}: \t \t \t {main_stats[keys]}")
# Out:
# mfb1KO: 	 	 	 (array([0.01453, 0.00456]), array([0.00668, 0.00142]))
# mfb1KO_mmr1KO: 	 	 	 (array([0.00789, 0.00471]), array([0.00072, 0.00152]))
# mmm1KO: 	 	 	 (array([0.02099, 0.00428]), array([0.00144, 0.00242]))
# mmr1KO: 	 	 	 (array([0.01455, 0.00484]), array([0.0067 , 0.00177]))
# num1KO: 	 	 	 (array([0.02101, 0.005  ]), array([0.00147, 0.0022 ]))
# WT: 	 	 	 (array([0.01435, 0.00464]), array([0.00668, 0.0014 ]))

# %%
for keys in test_stats.keys():
    print(f"{keys}: \t \t \t {test_stats[keys]}")

# %% [markdown]
# ## Defining datasets:

# %%
def tfms_for_test(stats, sz):
    test_norm = Normalize(stats)
    test_denorm = Denormalize(stats)
    val_crop = CropType.NO
    test_tfms = image_gen(test_norm, test_denorm,sz, crop_type=val_crop)
    return test_tfms

# %%
def get_data(path: str, sz, bs):
    create, lbl2index, lbl2index_test  = ImageClassifierData.prepare_from_path(path, val_name='val', bs=bs)
    main_stats_X = {lbl2index[key]: val for key, val in main_stats.items()}
#     test_stats_X= {lbl2index_test[key]: val for key, val in lbl2index_test.items()}
    tfms = tfms_from_stats(main_stats_X, sz, aug_tfms=[RandomDihedral()], pad=sz//8)
#     test_tfms = tfms_for_test(test_stats_X,sz)
#     tfms += (test_tfms, )
    print('\n class to index mapping:\n',lbl2index)
    return create(tfms)

# %%
data = get_data(PATH,SIZE, BATCH_SIZE)
# Out:
#  class to index mapping:
#  {'WT': 0, 'mfb1KO': 1, 'mfb1KO_mmr1KO': 2, 'mmm1KO': 3, 'mmr1KO': 4, 'num1KO': 5}

# %%
x, y = next(iter(data.trn_dl))

# %%
data.trn_dl.dataset.fnames
# Out:
# ['train\\WT\\WT_WP_E1_S0_F1_I2_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S0_F1_I2_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S0_F1_I2_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S0_F1_I2_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C11_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I10_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I11_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I11_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I11_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I11_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I11_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I11_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I12_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I12_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I12_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C11_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C12_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C13_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C14_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I13_C9_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I14_C9_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C11_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C12_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C13_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I15_C9_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I16_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I16_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I16_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I16_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I16_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I17_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I17_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I17_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I17_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I17_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I18_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I18_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I18_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I18_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I18_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I19_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I1_C9_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I20_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I2_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C12_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I3_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I4_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I4_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I4_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I4_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I4_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I4_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I5_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I5_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I5_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I5_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I6_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C11_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I7_C9_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I8_C1_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I8_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I8_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I8_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I8_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I8_C9_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C10_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C11_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C2_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C3_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C4_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C5_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C6_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C7_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C8_A0.tif',
#  'train\\WT\\WT_WP_E1_S2_F1_I9_C9_A0.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I10_C12_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I10_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I10_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I10_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I10_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I11_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C12_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I12_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I13_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I13_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I13_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I13_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I14_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I15_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I15_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I15_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I15_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I15_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I15_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I16_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C12_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I17_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I18_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I19_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I19_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I19_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I19_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I19_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I1_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I20_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I20_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I20_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I20_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I20_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I20_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I21_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I21_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I21_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I21_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I21_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I3_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I4_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I4_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I4_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I4_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I4_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I4_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C13_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I5_C9_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C11_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C13_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I6_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I7_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I7_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I7_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I7_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I7_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C10_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I8_C8_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C12_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C13_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C14_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C15_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C1_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C2_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C3_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C4_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C5_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C6_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C7_A0.tifstack.tif',
#  'train\\WT\\WT_WP_E2_S2_F1_I9_C8_A0.tifstack.tif',
#  'train\\mfb1KO\\0060-0120-0640.tifstack.tif',
#  'train\\mfb1KO\\0060-0126-0968.tifstack.tif',
#  'train\\mfb1KO\\0060-0128-0428.tifstack.tif',
#  'train\\mfb1KO\\0060-0460-0218.tifstack.tif',
#  'train\\mfb1KO\\0060-0540-0518.tifstack.tif',
#  'train\\mfb1KO\\0060-0606-0632.tifstack.tif',
#  'train\\mfb1KO\\0060-0636-1214.tifstack.tif',
#  'train\\mfb1KO\\0060-0654-1110.tifstack.tif',
#  'train\\mfb1KO\\0060-0722-0110.tifstack.tif',
#  'train\\mfb1KO\\0065-0556-1000.tifstack.tif',
#  'train\\mfb1KO\\0065-0680-1070.tifstack.tif',
#  'train\\mfb1KO\\0065-0874-0470.tifstack.tif',
#  'train\\mfb1KO\\0070-0130-1204.tifstack.tif',
#  'train\\mfb1KO\\0070-0132-0666.tifstack.tif',
#  'train\\mfb1KO\\0070-0140-0206.tifstack.tif',
#  'train\\mfb1KO\\0070-0178-0792.tifstack.tif',
#  'train\\mfb1KO\\0070-0182-0732.tifstack.tif',
#  'train\\mfb1KO\\0070-0190-0204.tifstack.tif',
#  'train\\mfb1KO\\0070-0196-0700.tifstack.tif',
#  'train\\mfb1KO\\0070-0236-0466.tifstack.tif',
#  'train\\mfb1KO\\0070-0244-0258.tifstack.tif',
#  'train\\mfb1KO\\0070-0256-1086.tifstack.tif',
#  'train\\mfb1KO\\0070-0260-0808.tifstack.tif',
#  'train\\mfb1KO\\0070-0270-0150.tifstack.tif',
#  'train\\mfb1KO\\0080-0784-1188.tifstack.tif',
#  'train\\mfb1KO\\0080-0866-0674.tifstack.tif',
#  'train\\mfb1KO\\0080-0888-0232.tifstack.tif',
#  'train\\mfb1KO\\0080-0906-0506.tifstack.tif',
#  'train\\mfb1KO\\0344-0570.tifstack.tif',
#  'train\\mfb1KO\\0438-0758.tifstack.tif',
#  'train\\mfb1KO\\0442-0400.tifstack.tif',
#  'train\\mfb1KO\\0504-0188.tifstack.tif',
#  'train\\mfb1KO\\0630-1086.tifstack.tif',
#  'train\\mfb1KO\\0756-0832.tifstack.tif',
#  'train\\mfb1KO\\0904-1008.tifstack.tif',
#  'train\\mfb1KO\\150_WP_E2_S2_F1_I19_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C15_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I10_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C13_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C14_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I11_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I12_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I12_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I12_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I12_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I12_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I13_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C13_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C14_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I14_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C13_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I15_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C13_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C14_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I1_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I2_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C14_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C15_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I3_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I4_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I5_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I6_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I6_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C10_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I7_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C11_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C12_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C13_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C14_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C1_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C8_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I8_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C2_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C3_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C4_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C5_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C6_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C7_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E1_S2_F1_I9_C9_A0.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I10_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I12_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I13_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I16_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I17_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I1_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I20_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I2_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I3_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I6_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I7_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I8_C1_A0.tifstack.tif',
#  'train\\mfb1KO\\mfb1KO_WP_E2_S2_F1_I9_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I10_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I10_C5_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I10_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I10_C8_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C11_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C13_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C14_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C16_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I11_C7_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I12_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I12_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I12_C5_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I13_C10_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I13_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I13_C2_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I13_C5_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I13_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I13_C8_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I14_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I16_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I17_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I1_C10_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I1_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I1_C4_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I1_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I21_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I2_C2_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I2_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I2_C4_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I2_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C11_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C12_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C13_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C4_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C8_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I3_C9_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C10_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C11_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C5_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C7_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I4_C9_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C11_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C4_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C5_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C7_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C8_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I5_C9_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I6_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I6_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I7_C1_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I7_C2_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I7_C3_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I7_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I7_C7_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I8_C2_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I8_C7_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I8_C8_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I9_C12_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I9_C2_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I9_C4_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I9_C6_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I9_C7_A0.tifstack.tif',
#  'train\\mfb1KO_mmr1KO\\mmr1KO_mfb1KO_WP_E2_S2_F1_I9_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I1_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I1_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I1_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I1_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I1_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I1_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I2_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I2_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I2_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I2_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I2_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S0_F1_I2_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I3_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C14_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C15_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C16_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C17_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C18_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C19_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C20_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C21_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I4_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C14_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C15_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C18_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C19_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I5_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C14_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C15_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C16_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I6_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I7_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I7_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I7_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1KO_WP_E1_S2_F1_I7_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I10_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C15_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C16_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C17_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I11_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I12_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I13_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I14_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I15_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I15_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I15_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I15_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I15_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I15_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C14_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I16_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I17_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C11_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I18_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I19_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C1_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I20_C8_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C14_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C2_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C4_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C5_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I8_C9_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C10_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C12_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C13_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C14_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C15_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C17_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C18_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C19_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C20_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C3_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C6_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C7_A0.tifstack.tif',
#  'train\\mmm1KO\\mmm1_WP_E1_S2_F1_I9_C8_A0.tifstack.tif',
#  'train\\mmr1KO\\0065-0144-0692.tifstack.tif',
#  'train\\mmr1KO\\0065-0230-0510.tifstack.tif',
#  'train\\mmr1KO\\0065-0320-0852.tifstack.tif',
#  'train\\mmr1KO\\0065-0344-0170.tifstack.tif',
#  'train\\mmr1KO\\0065-0366-0736.tifstack.tif',
#  'train\\mmr1KO\\0065-0414-0430.tifstack.tif',
#  'train\\mmr1KO\\0065-0476-0800.tifstack.tif',
#  'train\\mmr1KO\\0065-0580-1116.tifstack.tif',
#  'train\\mmr1KO\\0065-0582-1012.tifstack.tif',
#  'train\\mmr1KO\\0075-0422-0642.tifstack.tif',
#  'train\\mmr1KO\\0075-0428-0420.tifstack.tif',
#  'train\\mmr1KO\\0075-0448-0136.tifstack.tif',
#  'train\\mmr1KO\\0075-0452-0796.tifstack.tif',
#  'train\\mmr1KO\\0075-0468-0324.tifstack.tif',
#  'train\\mmr1KO\\0075-0470-0682.tifstack.tif',
#  'train\\mmr1KO\\0075-0486-0150.tifstack.tif',
#  'train\\mmr1KO\\0075-0512-0536.tifstack.tif',
#  'train\\mmr1KO\\0075-0520-0680.tifstack.tif',
#  'train\\mmr1KO\\0075-0526-0628.tifstack.tif',
#  'train\\mmr1KO\\0075-0536-0758.tifstack.tif',
#  'train\\mmr1KO\\0075-0554-0450.tifstack.tif',
#  'train\\mmr1KO\\0075-0560-0272.tifstack.tif',
#  'train\\mmr1KO\\0075-0584-0816.tifstack.tif',
#  'train\\mmr1KO\\0075-0598-1040.tifstack.tif',
#  'train\\mmr1KO\\0075-0610-0250.tifstack.tif',
#  'train\\mmr1KO\\0075-0626-0230.tifstack.tif',
#  'train\\mmr1KO\\0075-0626-0332.tifstack.tif',
#  'train\\mmr1KO\\0075-0636-1178.tifstack.tif',
#  'train\\mmr1KO\\0075-0668-0492.tifstack.tif',
#  'train\\mmr1KO\\0075-0676-1112.tifstack.tif',
#  'train\\mmr1KO\\0075-0690-1086.tifstack.tif',
#  'train\\mmr1KO\\0075-0694-0414.tifstack.tif',
#  'train\\mmr1KO\\0075-0710-0318.tifstack.tif',
#  'train\\mmr1KO\\0075-0734-0974.tifstack.tif',
#  'train\\mmr1KO\\0075-0740-0598.tifstack.tif',
#  'train\\mmr1KO\\0075-0740-0686.tifstack.tif',
#  'train\\mmr1KO\\0075-0768-0272.tifstack.tif',
#  'train\\mmr1KO\\0075-0768-0862.tifstack.tif',
#  'train\\mmr1KO\\0075-0778-1126.tifstack.tif',
#  'train\\mmr1KO\\0075-0794-0724.tifstack.tif',
#  'train\\mmr1KO\\0075-0800-0164.tifstack.tif',
#  'train\\mmr1KO\\0075-0802-1092.tifstack.tif',
#  'train\\mmr1KO\\0075-0817-0378.tifstack.tif',
#  'train\\mmr1KO\\0075-0830-0564.tifstack.tif',
#  'train\\mmr1KO\\0075-0835-1203.tifstack.tif',
#  'train\\mmr1KO\\0075-0842-0694.tifstack.tif',
#  'train\\mmr1KO\\0075-0868-0150.tifstack.tif',
#  'train\\mmr1KO\\0075-0888-0834.tifstack.tif',
#  'train\\mmr1KO\\0075-0900-1026.tifstack.tif',
#  'train\\mmr1KO\\0075-0904-0488.tifstack.tif',
#  'train\\mmr1KO\\0080-0102-0796.tifstack.tif',
#  'train\\mmr1KO\\0080-0114-0342.tifstack.tif',
#  'train\\mmr1KO\\0080-0122-0856.tifstack.tif',
#  'train\\mmr1KO\\0080-0150-0494.tifstack.tif',
#  ...]

# %% [markdown]
# ### Inspect loaded data:
#
# Displaying the same image with and without normalization.

# %%
# specify which image-index
idx = 0

# loading it from GPU to CPU
xx = x[idx].cpu().numpy().copy()
yy = y[idx]
# showing the image
#
#sp.axis('Off')
#sp.set_title("Norm", fontsize=11)
figure, _ ,_ = tiff.imshow(np.sum(xx, axis=0))
figure.set_size_inches(6,6)
figure.add_subplot(111)

figure2, _, _ = tiff.imshow(np.sum(data.trn_ds.denorm(xx,yy).squeeze() * 65536, axis=2)) # not very elegant atm. 
figure2.set_size_inches(6,6)
# Out:
# C:\Anaconda3\envs\fastai\lib\site-packages\matplotlib\axes\_base.py:3124: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))
# C:\Anaconda3\envs\fastai\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Anaconda3\envs\fastai\lib\site-packages\matplotlib\axes\_base.py:3124: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))

# %% [markdown]
# # Training setup

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## ResNet_with_Batchnorm
#
# Defining network architecture.

# %%
class BnLayer(nn.Module):
    def __init__(self, ni, nf, stride=2, kernel_size=3):
        super().__init__()
        self.conv = nn.Conv2d(ni, nf, kernel_size=kernel_size, stride=stride,
                              bias=False, padding=1)
        self.a = nn.Parameter(torch.zeros(nf,1,1))
        self.m = nn.Parameter(torch.ones(nf,1,1))
        
    def forward(self, x):
        x = F.relu(self.conv(x))
        x_chan = x.transpose(0,1).contiguous().view(x.size(1), -1)
        if self.training:
            self.means = x_chan.mean(1)[:,None,None]
            self.stds  = x_chan.std (1)[:,None,None]
        return (x-self.means) / self.stds *self.m + self.a

# %%
class ResnetLayer(BnLayer):
    def forward(self, x): return x + super().forward(x)

# %%
class Resnet(nn.Module):
    def __init__(self, layers, c):
        super().__init__()
        self.conv1 = nn.Conv2d(2, 10, kernel_size=5, stride=1, padding=2)
        self.layers = nn.ModuleList([BnLayer(layers[i], layers[i+1])
            for i in range(len(layers) - 1)])
        self.layers2 = nn.ModuleList([ResnetLayer(layers[i+1], layers[i + 1], 1)
            for i in range(len(layers) - 1)])
        self.layers3 = nn.ModuleList([ResnetLayer(layers[i+1], layers[i + 1], 1)
            for i in range(len(layers) - 1)])
        self.out = nn.Linear(layers[-1], c)
        
    def forward(self, x):
        x = self.conv1(x)
        for l,l2,l3 in zip(self.layers, self.layers2, self.layers3):
            x = l3(l2(l(x)))
        x = F.adaptive_max_pool2d(x, 1)
        x = x.view(x.size(0), -1)
        return F.log_softmax(self.out(x), dim=-1)

# %%
wd=1e-5 # weight-decay/L2 regularization

# %%
learn = ConvLearner.from_model_data(Resnet([10, 20, 40, 80, 160], 5), data)

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 2, 200, 200]),
#                            ('output_shape', [-1, 10, 200, 200]),
#                            ('trainable', True),
#                            ('nb_params', 510)])),
#              ('Conv2d-2',
#               OrderedDict([('input_shape', [-1, 10, 200, 200]),
#                            ('output_shape', [-1, 20, 100, 100]),
#                            ('trainable', True),
#                            ('nb_params', 1800)])),
#              ('BnLayer-3',
#               OrderedDict([('input_shape', [-1, 10, 200, 200]),
#                            ('output_shape', [-1, 20, 100, 100]),
#                            ('nb_params', 0)])),
#              ('Conv2d-4',
#               OrderedDict([('input_shape', [-1, 20, 100, 100]),
#                            ('output_shape', [-1, 20, 100, 100]),
#                            ('trainable', True),
#                            ('nb_params', 3600)])),
#              ('ResnetLayer-5',
#               OrderedDict([('input_shape', [-1, 20, 100, 100]),
#                            ('output_shape', [-1, 20, 100, 100]),
#                            ('nb_params', 0)])),
#              ('Conv2d-6',
#               OrderedDict([('input_shape', [-1, 20, 100, 100]),
#                            ('output_shape', [-1, 20, 100, 100]),
#                            ('trainable', True),
#                            ('nb_params', 3600)])),
#              ('ResnetLayer-7',
#               OrderedDict([('input_shape', [-1, 20, 100, 100]),
#                            ('output_shape', [-1, 20, 100, 100]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 20, 100, 100]),
#                            ('output_shape', [-1, 40, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 7200)])),
#              ('BnLayer-9',
#               OrderedDict([('input_shape', [-1, 20, 100, 100]),
#                            ('output_shape', [-1, 40, 50, 50]),
#                            ('nb_params', 0)])),
#              ('Conv2d-10',
#               OrderedDict([('input_shape', [-1, 40, 50, 50]),
#                            ('output_shape', [-1, 40, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 14400)])),
#              ('ResnetLayer-11',
#               OrderedDict([('input_shape', [-1, 40, 50, 50]),
#                            ('output_shape', [-1, 40, 50, 50]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 40, 50, 50]),
#                            ('output_shape', [-1, 40, 50, 50]),
#                            ('trainable', True),
#                            ('nb_params', 14400)])),
#              ('ResnetLayer-13',
#               OrderedDict([('input_shape', [-1, 40, 50, 50]),
#                            ('output_shape', [-1, 40, 50, 50]),
#                            ('nb_params', 0)])),
#              ('Conv2d-14',
#               OrderedDict([('input_shape', [-1, 40, 50, 50]),
#                            ('output_shape', [-1, 80, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 28800)])),
#              ('BnLayer-15',
#               OrderedDict([('input_shape', [-1, 40, 50, 50]),
#                            ('output_shape', [-1, 80, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 80, 25, 25]),
#                            ('output_shape', [-1, 80, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 57600)])),
#              ('ResnetLayer-17',
#               OrderedDict([('input_shape', [-1, 80, 25, 25]),
#                            ('output_shape', [-1, 80, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-18',
#               OrderedDict([('input_shape', [-1, 80, 25, 25]),
#                            ('output_shape', [-1, 80, 25, 25]),
#                            ('trainable', True),
#                            ('nb_params', 57600)])),
#              ('ResnetLayer-19',
#               OrderedDict([('input_shape', [-1, 80, 25, 25]),
#                            ('output_shape', [-1, 80, 25, 25]),
#                            ('nb_params', 0)])),
#              ('Conv2d-20',
#               OrderedDict([('input_shape', [-1, 80, 25, 25]),
#                            ('output_shape', [-1, 160, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 115200)])),
#              ('BnLayer-21',
#               OrderedDict([('input_shape', [-1, 80, 25, 25]),
#                            ('output_shape', [-1, 160, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 160, 13, 13]),
#                            ('output_shape', [-1, 160, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 230400)])),
#              ('ResnetLayer-23',
#               OrderedDict([('input_shape', [-1, 160, 13, 13]),
#                            ('output_shape', [-1, 160, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Conv2d-24',
#               OrderedDict([('input_shape', [-1, 160, 13, 13]),
#                            ('output_shape', [-1, 160, 13, 13]),
#                            ('trainable', True),
#                            ('nb_params', 230400)])),
#              ('ResnetLayer-25',
#               OrderedDict([('input_shape', [-1, 160, 13, 13]),
#                            ('output_shape', [-1, 160, 13, 13]),
#                            ('nb_params', 0)])),
#              ('Linear-26',
#               OrderedDict([('input_shape', [-1, 160]),
#                            ('output_shape', [-1, 5]),
#                            ('trainable', True),
#                            ('nb_params', 805)]))])

# %%
# %time learn.fit(1e-2, 8, cycle_len=1, wds=wd)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=8), HTML(value='')))
# EPOCH 0 ---------------------------------------- STEP 0
# mean: [22.7  22.5   5.2  15.15 32.25]
# stdev: [4.57275 4.66369 2.5219  3.66436 6.09816]
#
# [WT]: 22.86%
# [mfb1KO]: 44.29%
# [mfb1KO_mmr1KO]:  0.0%
# [mmm1KO_230]: 100.0%
# [mmr1KO]: 44.29%
# epoch      trn_loss   val_loss   accuracy
#     0      8.723474   1.909527   0.403571
# EPOCH 1 ---------------------------------------- STEP 1
# mean: [22.85 22.5   5.3  15.05 32.2 ]
# stdev: [4.24588 4.84252 2.32594 3.42746 3.66879]
#
# [WT]: 72.86%
# [mfb1KO]: 14.29%
# [mfb1KO_mmr1KO]:  0.0%
# [mmm1KO_230]: 100.0%
# [mmr1KO]: 68.57%
#     1      8.397361   10.801739  0.514286
# EPOCH 2 ---------------------------------------- STEP 2
# mean: [22.4 22.8  5.3 15.  32.1]
# stdev: [4.50999 5.42771 3.62077 5.41295 5.88982]
#
# [WT]: 57.14%
# [mfb1KO]: 18.57%
# [mfb1KO_mmr1KO]:  0.0%
# [mmm1KO_230]: 100.0%
# [mmr1KO]: 42.86%
#     2      7.677144   12.466029  0.421429
# EPOCH 3 ---------------------------------------- STEP 3
# mean: [22.9  22.55  5.45 15.2  31.8 ]
# stdev: [5.77841 5.48156 3.00791 4.6     5.24023]
#
# [WT]: 4.286%
# [mfb1KO]: 25.71%
# [mfb1KO_mmr1KO]: 97.14%
# [mmm1KO_230]: 28.57%
# [mmr1KO]: 87.14%
#     3      5.524957   1.634658   0.45
# EPOCH 4 ---------------------------------------- STEP 4
# mean: [22.6  22.75  5.25 15.2  32.15]
# stdev: [5.44426 4.31132 3.08018 4.36578 5.2941 ]
#
# [WT]: 95.71%
# [mfb1KO]:  0.0%
# [mfb1KO_mmr1KO]:  0.0%
# [mmm1KO_230]: 100.0%
# [mmr1KO]: 21.43%
#     4      5.878395   9.808289   0.417857
# EPOCH 5 ---------------------------------------- STEP 5
# mean: [23.2  22.45  5.2  15.1  31.7 ]
# stdev: [6.72012 4.72731 3.31059 5.18556 5.41387]
#
# [WT]: 5.714%
# [mfb1KO]: 4.286%
# [mfb1KO_mmr1KO]:  0.0%
# [mmm1KO_230]: 100.0%
# [mmr1KO]: 100.0%
#     5      6.107684   14.221352  0.4
# EPOCH 6 ---------------------------------------- STEP 6
# mean: [22.55 22.35  5.25 15.35 32.4 ]
# stdev: [4.95454 7.16432 3.08018 5.22757 6.04483]
#
# [WT]: 75.71%
# [mfb1KO]: 50.0%
# [mfb1KO_mmr1KO]: 28.57%
# [mmm1KO_230]: 100.0%
# [mmr1KO]: 31.43%
#     6      4.832026   1.833123   0.553571
# EPOCH 7 ---------------------------------------- STEP 7
# mean: [22.7  22.5   5.2  15.05 32.35]
# stdev: [4.55082 4.79062 2.46171 3.54225 5.27518]
#
# [WT]: 2.857%
# [mfb1KO]: 2.857%
# [mfb1KO_mmr1KO]: 37.14%
# [mmm1KO_230]: 97.14%
# [mmr1KO]: 95.71%
#     7      3.652515   2.23616    0.421429
#
# Wall time: 2min 24s
# [array([2.23616]), 0.42142856972558157]

# %%
f = plt.figure()
x = learn.sched.plot_loss()
plt.ylabel('Loss')
plt.xlabel('Iterations')
plt.show()

# %% [markdown]
# #### Run some more cylces - error & accuracy should continuously improve
#
# Note: cycle len = number of epochs per cycle

# %%
# %time learn.fit(1e-2, 8, wds=wd, cycle_len=10, use_clr=(20,8, 0.95, 0.85))

# %%
# %time learn.fit(1e-3, 2, wds=wd, cycle_len=20, use_clr=(20,8, 0.95, 0.85))

# %%
# %time learn.fit(1e-3, 2, wds=wd, cycle_len=20, use_clr=(20,8, 0.95, 0.85), best_save_name='YNet_Res_v5.1_redo_1')

# %% [markdown]
# ## Analysis/Model evaluation
#
# This is one of the major areas that needs improvement in our workflow. The tools we have so far (confusion matrix and manual inpsection of images) are essential but definitely not sufficient to ensure that our model learns something biologicaly relevant. Ideas are welcome!

# %% [markdown]
# ### ...after training

# %%
## Load model:
learn.load('Objective_A_Resnet_per_class_2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-b77c0ef9b559> in <module>()
#       1 ## Load model:
# ----> 2 learn.load('Objective_A_Resnet_per_class_2')
#
# ~\DEV\GitHub\Test_dev\YNet_dev\resources\learner.py in load(self, name)
#     114
#     115     def load(self, name):
# --> 116         load_model(self.model, self.get_model_path(name))
#     117         if hasattr(self, 'swa_model'): load_model(self.swa_model, self.get_model_path(name)[:-3] + '-swa.h5')
#     118
#
# ~\DEV\GitHub\Test_dev\YNet_dev\resources\torch_imports.py in load_model(m, p)
#      25 def children(m): return m if isinstance(m, (list, tuple)) else list(m.children())
#      26 def save_model(m, p): torch.save(m.state_dict(), p)
# ---> 27 def load_model(m, p): m.load_state_dict(torch.load(p, map_location=lambda storage, loc: storage))
#      28
#      29 def load_pre(pre, f, fn):
#
# C:\Anaconda3\envs\fastai\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module)
#     263             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     264         new_fd = True
# --> 265         f = open(f, 'rb')
#     266     try:
#     267         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/yeast_v5.1/models\\Objective_A_Resnet_per_class_2.h5'

# %%
# %time learn.fit(1e-10, 1, wds=wd, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# EPOCH 0 ---------------------------------------- STEP 8
# mean: [22.8  22.35  5.15 15.   32.2 ]
# stdev: [4.23792 5.11151 2.83328 4.44972 5.65332]
#
# [WT]: 62.86%
# [mfb1KO]: 11.43%
# [mfb1KO_mmr1KO]: 45.71%
# [mmm1KO_230]: 97.14%
# [mmr1KO]: 78.57%
# epoch      trn_loss   val_loss   accuracy
#     0      0.983897   1.411717   0.560714
#
# Wall time: 17.8 s
# [array([1.41172]), 0.5607142840112959]

# %%
log_preds, y = learn.TTA() # run predictions with TTA

# %% [markdown]
# ### Confusion matrix

# %%
# Plot confusion matrix 
log_preds_mean = np.mean(log_preds, axis=0)
preds = np.argmax(log_preds_mean, axis=1)
cm = confusion_matrix(preds,y)
plot_confusion_matrix(cm, data.classes)
# Out:
# [[41  5  0  0 11]
#  [ 0  8  0  0  3]
#  [ 0  0 15  1  0]
#  [ 0  0 20 34  0]
#  [29 57  0  0 56]]

# %% [markdown]
# ### Analyse images

# %% [markdown]
# #### Show random correct/incorrectly classified images:

# %%
log_preds_mean = np.mean(log_preds, axis=0) # averages predictions on original + 4 TTA images
preds = np.argmax(log_preds_mean, axis=1) # converts into 0 or 1

# %%
# probs = np.exp(log_preds_mean[:,0]) # prediction(WT)
probs = np.exp(log_preds_mean) # predictions

# %%
def rand_by_mask(mask): return np.random.choice(np.where(mask)[0], 4, replace=False)
def rand_by_correct(is_correct): return rand_by_mask((preds == data.val_y)==is_correct)

# %%
def plots(ims, channel, figsize=(12,6), rows=1, titles=None):
    f = plt.figure(figsize=figsize)
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None: sp.set_title(titles[i], fontsize=11)
        if channel is not None: plt.imshow(ims[i,channel,:,:]) 
        else: plt.imshow(np.sum(ims, axis=1)[i,:,:])

# %%
def plot_val_with_title_from_ds_no_denorm(idxs, title, channel=None):
    
    imgs = np.stack(data.val_ds[x][0] for x in idxs) # get images by idx
    corr_lbl = np.stack(data.val_ds[x][1] for x in idxs) # get correct label from data.val_ds by idx
    pred_lbl = np.stack(preds[x] for x in idxs) # get predicted label from preds by idx
    p_max = [np.amax(probs[x,:]) for x in idxs] # get highes probability from probs by idx
    
    title_fin = [f"true = {corr_lbl[x]}\n predicted: {pred_lbl[x]}\n  p = {p_max[x]}" for x in corr_lbl]
    print(title)
    
    return plots(imgs, channel, rows=1, titles=title_fin, figsize=(16,8))

# %% [markdown]
# ### Plot images according to predictions

# %%
# load from ds - not denormalized! 
plot_val_with_title_from_ds_no_denorm(rand_by_correct(True), "Correctly classified")
#optionally pass channel arg. to select single channel

# %%
plot_val_with_title_from_ds_no_denorm(rand_by_correct(False), "Incorrectly classified")

# %% [markdown]
# #### Show most correct/incorrectly classified images per class:

# %%
def most_by_mask(mask, y, mult):
    idxs = np.where(mask)[0]
    return idxs[np.argsort(mult * probs[:,y][idxs])[:4]]

def most_by_correct(y, is_correct): 
    mult = -1 if is_correct else 1
    return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), y, mult)

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(0, True), "Most correctly classified WT")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(0, False), "Most incorrectly classified WT") # logic?

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(1, True), "Most correctly classified mfb1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(1, False), "Most incorrectly classified mfb1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(2, True), "Most correctly classified mfb1KO-mmr1KO")

# %%
plot_val_with_title_from_ds_no_denorm(most_by_correct(3, True), "Most correctly classified mmr1KO")

# %%
# etc.

# %% [markdown]
# #### Show (most) uncertain images

# %%
most_uncertain = t = np.argsort(np.amax(probs, axis = 1))[:6] # get best "guess" per image and list the least confident ones
plot_val_with_title_from_ds_no_denorm(most_uncertain, "Most uncertain predictions")
