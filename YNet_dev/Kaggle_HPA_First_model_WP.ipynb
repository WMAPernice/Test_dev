# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
import skimage.external.tifffile as tiff

from common import Statistics, dataset_source
from resources.conv_learner import *
from resources.plots import *
from pprint import pprint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
PATH = "datasets/Kaggle_HPA_2018/"
data_path = Path(PATH)

# %%
NUM_CLASSES = 27
bs = 64
sz = [4,224,224]

# %%
# setting up a list of a random 20% of images in train as the validation set

lbl_csv = PATH + 'train_10perc_v2.csv'
n = len(list(open(lbl_csv))) -1
val_idxs = get_cv_idxs(n)

# %%
def get_data(path, lbl_csv, val_idxs, sz, bs, aug_tfms):
    
    augs = [RandomDihedral()
           ]

    tfms = tfms_with_IntNorm(sz, aug_tfms=aug_tfms, crop_type=CropType.CENTER)
    data = ImageClassifierData.from_csv(PATH, 'rand_10perc_v2_all_chan', lbl_csv, val_idxs = val_idxs,tfms=tfms, bs=bs, suffix = '.tiff')
    
    return data

# %%
augs = [RandomDihedral()]

# initialize data object
data = get_data(PATH, lbl_csv, val_idxs, sz, bs, aug_tfms = augs)

# %%
data.__dict__.keys()
# Out:
# dict_keys(['path', 'bs', 'num_workers', 'classes', 'trn_dl', 'val_dl', 'fix_dl', 'aug_dl', 'test_dl', 'test_aug_dl'])

# %%
x, y = next(iter(data.trn_dl))

# %%
def to_label(y):
    ind = [i for i, p in enumerate(y) if y[i]==1]
    return(ind)

# %%
# inspect images
plt.style.use('seaborn-white')

idx = 2

im = to_np(x)[idx]

lbl = to_label(to_np(y)[idx])
print(lbl)

fig, ax = plt.subplots(1,4, figsize=(16,10))
for i, ax in enumerate(ax.flat):
    ax.imshow(im[i])
# Out:
# [0, 3]

# %%
# List of label identities:

cell_location_label = {
0:  'Nucleoplasm',
1:  'Nuclear membrane',
2:  'Nucleoli',   
3:  'Nucleoli fibrillar center',
4:  'Nuclear speckles',
5:  'Nuclear bodies',
6:  'Endoplasmic reticulum',   
7:  'Golgi apparatus',
8:  'Peroxisomes',
9:  'Endosomes',
10:  'Lysosomes',
11:  'Intermediate filaments',
12:  'Actin filaments',
13:  'Focal adhesion sites',   
14:  'Microtubules',
15:  'Microtubule ends',  
16:  'Cytokinetic bridge',   
17:  'Mitotic spindle',
18:  'Microtubule organizing center',  
19:  'Centrosome',
20:  'Lipid droplets',
21:  'Plasma membrane',   
22:  'Cell junctions', 
23:  'Mitochondria',
24:  'Aggresome',
25:  'Cytosol',
26:  'Cytoplasmic bodies',   
27:  'Rods & rings' }

# %% [markdown]
# # training

# %%
arch = resnet18_c

# %%
learn = ConvLearner.pretrained(arch, data, ps=0.25, opt_fn=optim.Adam, pretrained=False)

# %%
learn.unfreeze()

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 4, 224, 224]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', True),
#                            ('nb_params', 12544)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 112, 112]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 112, 112]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-11',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-12',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-13',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-14',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-15',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 36864)])),
#              ('BatchNorm2d-16',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-17',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-18',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 64, 56, 56]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('Conv2d-24',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-25',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-26',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-27',
#               OrderedDict([('input_shape', [-1, 64, 56, 56]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 147456)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-34',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 128, 28, 28]),
#                            ('nb_params', 0)])),
#              ('Conv2d-35',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-36',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-37',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-38',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-39',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-42',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-43',
#               OrderedDict([('input_shape', [-1, 128, 28, 28]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-44',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-45',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-46',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-47',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 589824)])),
#              ('BatchNorm2d-48',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-49',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-50',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 256, 14, 14]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1179648)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Conv2d-56',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-57',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-58',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-59',
#               OrderedDict([('input_shape', [-1, 256, 14, 14]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 2359296)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('BasicBlock-66',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 7, 7]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-67',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-68',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 512, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-69',
#               OrderedDict([('input_shape', [-1, 512, 7, 7]),
#                            ('output_shape', [-1, 1024, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-70',
#               OrderedDict([('input_shape', [-1, 1024, 1, 1]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-71',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Dropout-72',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 1024]),
#                            ('nb_params', 0)])),
#              ('Linear-73',
#               OrderedDict([('input_shape', [-1, 1024]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 524800)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-75',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-76',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-77',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 27]),
#                            ('trainable', True),
#                            ('nb_params', 13851)])),
#              ('Sigmoid-78',
#               OrderedDict([('input_shape', [-1, 27]),
#                            ('output_shape', [-1, 27]),
#                            ('nb_params', 0)]))])

# %%
wd=1e-5 # weight-decay/L2 regularization

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   0%|                                                                                                                                                                                                                 | 0/39 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d81c6bd29d71> in <module>()
# ----> 1 learn.lr_find()
#
# ~\DEV\GitHub\Test_dev\YNet_dev\resources\learner.py in lr_find(self, start_lr, end_lr, wds, linear, **kwargs)
#     358         layer_opt = self.get_layer_opt(start_lr, wds)
#     359         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 360         self.fit_gen(self.model, self.data, layer_opt, 1, **kwargs)
#     361         self.load('tmp')
#     362
#
# ~\DEV\GitHub\Test_dev\YNet_dev\resources\learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, adjust_class, **kwargs)
#     261                    metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16,
#     262                    swa_model=self.swa_model if use_swa else None, swa_start=swa_start,
# --> 263                    swa_eval_freq=swa_eval_freq, adjust_class=adjust_class, **kwargs)  # (!) adjust class
#     264
#     265     def get_layer_groups(self):
#
# ~\DEV\GitHub\Test_dev\YNet_dev\resources\model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, adjust_class, **kwargs)
#     172
#     173         for (*x, y) in t:
# --> 174             print_dist(y)
#     175
#     176             batch_num += 1
#
# ~\DEV\GitHub\Test_dev\YNet_dev\resources\model.py in __call__(self, y)
#     502     def __call__(self, y):
#     503         y = y.cpu().numpy().copy()  # gonna eat up a lot of memory
# --> 504         occurences = np.bincount(y, minlength=self.num_classes)
#     505
#     506         percentages = np.array([int(100 * count / sum(occurences)) for count in occurences])
#
# ValueError: object too deep for desired array
