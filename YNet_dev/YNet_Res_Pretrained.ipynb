# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
import skimage.external.tifffile as tiff

from common import Statistics, dataset_source
from resources.conv_learner import *
from resources.plots import *

# %%
PATH = "../datasets/yeast_v4"
data_path = Path(PATH)

# %%
CLASSES = ('WT', 'mfb1KO', 'mfb1KO_mmr1KO', 'mmr1KO')
NUM_CLASSES = len(CLASSES)
BATCH_SIZE = 64
SIZE = 200
NAME = "ResNet34_pretrained_per_class"

# %% [markdown]
# ## Statistics and Data Exploration

# %%
stats_name = "yeast_v4_per_class.dict"
test_dirs, train_dirs = dataset_source(data_path)
stats_dict = Statistics.per_class(test_dirs, train_dirs,save_name=stats_name)

# for three channels
for key, stats in stats_dict.items():
    stats_dict[key] = [np.append(stats[0],0), np.append(stats[1],1)]
# Out:
# working on: mfb1KO
# working on: mfb1KO_mmr1KO
# working on: mmr1KO
# working on: WT

# %%
def get_data(path: str, sz, bs, stats):
    create, lbl2index = ImageClassifierData.prepare_from_path(path, val_name='test', bs=bs)
    stats_dict = {lbl2index[key]: val for key, val in stats.items()}
    tfms = tfms_from_stats(stats_dict, sz, aug_tfms=[RandomDihedral(), AddDimension()], pad=sz//8) #even without transformations and padding -> failure
    print('\n class to index mapping:\n',lbl2index)
    return create(tfms)

### the eventual sub-function of ImageClassifierData (read_dirs) expects subdirectories for each class: 
### e.g. all "test/cat.png" images should be in a "cat" folder.

# %%
data = get_data(PATH,SIZE, BATCH_SIZE,stats_dict)
# Out:
#  class to index mapping:
#  {'WT': 0, 'mfb1KO': 1, 'mfb1KO_mmr1KO': 2, 'mmr1KO': 3}

# %%
x, y = next(iter(data.trn_dl))

# %%
idx = 1
tiff.imshow(data.trn_ds.denorm(x[idx], y[idx]).squeeze()[:,:,1]); #denorm function called has a rollaxis() hence indexing changes.
# Out:
# /home/user/anaconda3/envs/fastai/lib/python3.6/site-packages/matplotlib/axes/_base.py:3124: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))

# %% [markdown]
# ## Model definition and ConvLearner

# %%
arch = resnet34

# %%
learn = ConvLearner.pretrained(arch, data)

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d81c6bd29d71> in <module>()
# ----> 1 learn.lr_find()
#
# ~/Projects/WPColumbia/YNet_dev/resources/learner.py in lr_find(self, start_lr, end_lr, wds, linear, **kwargs)
#     348         layer_opt = self.get_layer_opt(start_lr, wds)
#     349         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 350         self.fit_gen(self.model, self.data, layer_opt, 1, **kwargs)
#     351         self.load('tmp')
#     352
#
# ~/Projects/WPColumbia/YNet_dev/resources/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, use_swa, swa_start, swa_eval_freq, **kwargs)
#     251                    metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16,
#     252                    swa_model=self.swa_model if use_swa else None, swa_start=swa_start,
# --> 253                    swa_eval_freq=swa_eval_freq, **kwargs)
#     254
#     255     def get_layer_groups(self):
#
# ~/Projects/WPColumbia/YNet_dev/resources/model.py in fit(model, data, n_epochs, opt, crit, metrics, callbacks, stepper, swa_model, swa_start, swa_eval_freq, **kwargs)
#     181
#     182
# --> 183         per_class_accuracies(cur_data.val_dl, model, epoch) # (!) added per class accuracy
#     184
#     185         if not all_val:
#
# ~/Projects/WPColumbia/YNet_dev/resources/model.py in per_class_accuracies(data_loader, model, epoch)
#     348     data_iter = iter(data_loader)
#     349
# --> 350     for x, y in data_iter:
#     351         # do the computation on the gpu after switch to the cpu
#     352         x = x if IS_TORCH_04 else V(x)
#
# ~/Projects/WPColumbia/YNet_dev/resources/dataloader.py in __iter__(self)
#      93                 # avoid py3.6 issue where queue is infinite and can result in memory exhaustion
#      94                 for c in chunk_iter(iter(self.batch_sampler), self.num_workers * 10):
# ---> 95                     for batch in e.map(self.get_batch, c):
#      96                         yield get_tensor(batch, self.pin_memory, self.half)
#
# ~/anaconda3/envs/fastai/lib/python3.6/concurrent/futures/_base.py in result_iterator()
#     584                     # Careful not to keep a reference to the popped future
#     585                     if timeout is None:
# --> 586                         yield fs.pop().result()
#     587                     else:
#     588                         yield fs.pop().result(end_time - time.time())
#
# ~/anaconda3/envs/fastai/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~/anaconda3/envs/fastai/lib/python3.6/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~/anaconda3/envs/fastai/lib/python3.6/concurrent/futures/thread.py in run(self)
#      54
#      55         try:
# ---> 56             result = self.fn(*self.args, **self.kwargs)
#      57         except BaseException as exc:
#      58             self.future.set_exception(exc)
#
# ~/Projects/WPColumbia/YNet_dev/resources/dataloader.py in get_batch(self, indices)
#      80
#      81     def get_batch(self, indices):
# ---> 82         res = self.np_collate([self.dataset[i] for i in indices])
#      83         if self.transpose:   res[0] = res[0].T
#      84         if self.transpose_y: res[1] = res[1].T
#
# ~/Projects/WPColumbia/YNet_dev/resources/dataloader.py in <listcomp>(.0)
#      80
#      81     def get_batch(self, indices):
# ---> 82         res = self.np_collate([self.dataset[i] for i in indices])
#      83         if self.transpose:   res[0] = res[0].T
#      84         if self.transpose_y: res[1] = res[1].T
#
# ~/Projects/WPColumbia/YNet_dev/resources/dataset.py in __getitem__(self, idx)
#     185             xs, ys = zip(*[self.get1item(i) for i in range(*idx.indices(self.n))])
#     186             return np.stack(xs), ys
# --> 187         return self.get1item(idx)
#     188
#     189     def __len__(self):
#
# ~/Projects/WPColumbia/YNet_dev/resources/dataset.py in get1item(self, idx)
#     179     def get1item(self, idx):
#     180         x, y = self.get_x(idx), self.get_y(idx)
# --> 181         return self.get(self.transform, x, y)
#     182
#     183     def __getitem__(self, idx):
#
# ~/Projects/WPColumbia/YNet_dev/resources/dataset.py in get(self, tfm, x, y)
#     191
#     192     def get(self, tfm, x, y):
# --> 193         return (x, y) if tfm is None else tfm(x, y)
#     194
#     195     @abstractmethod
#
# ~/Projects/WPColumbia/YNet_dev/resources/transforms.py in __call__(self, im, y)
#     747
#     748
# --> 749     def __call__(self, im, y=None): return compose(im, y, self.tfms)
#     750
#     751     def __repr__(self): return str(self.tfms)
#
# ~/Projects/WPColumbia/YNet_dev/resources/transforms.py in compose(im, y, fns)
#     718
#     719     for fn in fns:
# --> 720         im, y = fn(im, y)
#     721     return im if y is None else (im, y)
#     722
#
# ~/Projects/WPColumbia/YNet_dev/resources/transforms.py in __call__(self, x, y)
#     221             m,s = self.m, self.s
#     222
# --> 223         x = (x-m) / s
#     224
#     225         if self.tfm_y==TfmType.PIXEL and y is not None: y = (y-self.m)/self.s
#
# ValueError: operands could not be broadcast together with shapes (200,200,2) (3,)
